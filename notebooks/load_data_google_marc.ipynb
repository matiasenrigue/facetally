# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
from google.cloud import storage
from face_tally.params import *

# %% [markdown]
# # Load raw data

# %%
# Project path
project_root = LOCAL_DATA_PATH

# Directories path
test_image_folder = os.path.join(LOCAL_DATA_PATH, "image_data")
path_annot = os.path.join(LOCAL_DATA_PATH, 'bbox_train.csv')

# %%
df = pd.read_csv(path_annot)
df.head()
# Out:
#         Name  width  height  xmin  ymin  xmax  ymax
# 0  10001.jpg    612     408   192   199   230   235
# 1  10001.jpg    612     408   247   168   291   211
# 2  10001.jpg    612     408   321   176   366   222
# 3  10001.jpg    612     408   355   183   387   214
# 4  10002.jpg    612     408   339   165   378   202

# %% [markdown]
# # Check which images have anotations. Only those ones are pushed to Google Cloud

# %%
annotated_images_names = df.Name.unique()
len(annotated_images_names)
# Out:
# 5733

# %% [markdown]
# # Create bucket

# %%
# !$BUCKET_NAME
# Out:
# zsh:1: command not found: facetally_data

# %%
# !gsutil mb -l $GCP_REGION -p $GCP_PROJECT gs://$BUCKET_NAME
# Out:
# Creating gs://facetally_data/...

# %% [markdown]
# # Load data to Cloud Storage Bucket

# %%
# Create a Storage client
storage_client = storage.Client()

# Get the bucket
bucket = storage_client.bucket(BUCKET_NAME)

# Directories path
local_directory_images = os.path.join(LOCAL_DATA_PATH, "image_data")
local_directory_annotations = os.path.join(LOCAL_DATA_PATH)

# Destination directory in the bucket
destination_directory_images = 'image_data/'  # Destination folder in the bucket

# Filter images with annotations
raw_images_names = os.listdir(local_directory_images)
filtered_images_names = []
for image in raw_images_names:
    for annotation in annotated_images_names:
        if image == annotation:
            filtered_images_names.append(image)

# %%
# Upload the images
print(f"Uploading images")
for count, filename in enumerate(filtered_images_names):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        local_image_path = os.path.join(local_directory_images, filename)
        destination_blob_name = os.path.join(destination_directory_images, filename)

        # Create a Blob object and upload the image file to the bucket
        blob = bucket.blob(destination_blob_name)
        if blob.exists():
            print(f"The file '{destination_blob_name}' already exists, won't be pushed. Count: {count + 1}")
        else:
            blob.upload_from_filename(local_image_path)
            print(f"Image '{filename}' uploaded to Google Cloud Storage: {destination_blob_name}. Count: {count + 1}")
print(f"Process finished")
# Out:
# Uploading images
# Image '15603.jpg' uploaded to Google Cloud Storage: image_data/15603.jpg. Count: 1
# Image '13153.jpg' uploaded to Google Cloud Storage: image_data/13153.jpg. Count: 2
# Image '12753.jpg' uploaded to Google Cloud Storage: image_data/12753.jpg. Count: 3
# Image '15241.jpg' uploaded to Google Cloud Storage: image_data/15241.jpg. Count: 4
# Image '10028.jpg' uploaded to Google Cloud Storage: image_data/10028.jpg. Count: 5
# Image '16053.jpg' uploaded to Google Cloud Storage: image_data/16053.jpg. Count: 6
# Image '17084.jpg' uploaded to Google Cloud Storage: image_data/17084.jpg. Count: 7
# Image '16335.jpg' uploaded to Google Cloud Storage: image_data/16335.jpg. Count: 8
# Image '16231.jpg' uploaded to Google Cloud Storage: image_data/16231.jpg. Count: 9
# Image '14072.jpg' uploaded to Google Cloud Storage: image_data/14072.jpg. Count: 10
# Image '16428.jpg' uploaded to Google Cloud Storage: image_data/16428.jpg. Count: 11
# Image '17546.jpg' uploaded to Google Cloud Storage: image_data/17546.jpg. Count: 12
# Image '17717.jpg' uploaded to Google Cloud Storage: image_data/17717.jpg. Count: 13
# Image '13947.jpg' uploaded to Google Cloud Storage: image_data/13947.jpg. Count: 14
# Image '11412.jpg' uploaded to Google Cloud Storage: image_data/11412.jpg. Count: 15
# Image '13173.jpg' uploaded to Google Cloud Storage: image_data/13173.jpg. Count: 16
# Image '11691.jpg' uploaded to Google Cloud Storage: image_data/11691.jpg. Count: 17
# Image '13806.jpg' uploaded to Google Cloud Storage: image_data/13806.jpg. Count: 18
# Image '17776.jpg' uploaded to Google Cloud Storage: image_data/17776.jpg. Count: 19
# Image '10934.jpg' uploaded to Google Cloud Storage: image_data/10934.jpg. Count: 20
# Image '16263.jpg' uploaded to Google Cloud Storage: image_data/16263.jpg. Count: 21
# Image '17756.jpg' uploaded to Google Cloud Storage: image_data/17756.jpg. Count: 22
# Image '16227.jpg' uploaded to Google Cloud Storage: image_data/16227.jpg. Count: 23
# Image '12572.jpg' uploaded to Google Cloud Storage: image_data/12572.jpg. Count: 24
# Image '15545.jpg' uploaded to Google Cloud Storage: image_data/15545.jpg. Count: 25
# Image '16291.jpg' uploaded to Google Cloud Storage: image_data/16291.jpg. Count: 26
# Image '11359.jpg' uploaded to Google Cloud Storage: image_data/11359.jpg. Count: 27
# Image '14579.jpg' uploaded to Google Cloud Storage: image_data/14579.jpg. Count: 28
# Image '10790.jpg' uploaded to Google Cloud Storage: image_data/10790.jpg. Count: 29
# Image '13086.jpg' uploaded to Google Cloud Storage: image_data/13086.jpg. Count: 30
# Image '10073.jpg' uploaded to Google Cloud Storage: image_data/10073.jpg. Count: 31
# Image '15096.jpg' uploaded to Google Cloud Storage: image_data/15096.jpg. Count: 32
# Image '14521.jpg' uploaded to Google Cloud Storage: image_data/14521.jpg. Count: 33
# Image '16875.jpg' uploaded to Google Cloud Storage: image_data/16875.jpg. Count: 34
# Image '11699.jpg' uploaded to Google Cloud Storage: image_data/11699.jpg. Count: 35
# Image '17436.jpg' uploaded to Google Cloud Storage: image_data/17436.jpg. Count: 36
# Image '14867.jpg' uploaded to Google Cloud Storage: image_data/14867.jpg. Count: 37
# Image '11861.jpg' uploaded to Google Cloud Storage: image_data/11861.jpg. Count: 38
# Image '16894.jpg' uploaded to Google Cloud Storage: image_data/16894.jpg. Count: 39
# Image '17683.jpg' uploaded to Google Cloud Storage: image_data/17683.jpg. Count: 40
# Image '15740.jpg' uploaded to Google Cloud Storage: image_data/15740.jpg. Count: 41
# Image '17011.jpg' uploaded to Google Cloud Storage: image_data/17011.jpg. Count: 42
# Image '10282.jpg' uploaded to Google Cloud Storage: image_data/10282.jpg. Count: 43
# Image '15606.jpg' uploaded to Google Cloud Storage: image_data/15606.jpg. Count: 44
# Image '13588.jpg' uploaded to Google Cloud Storage: image_data/13588.jpg. Count: 45
# Image '14450.jpg' uploaded to Google Cloud Storage: image_data/14450.jpg. Count: 46
# Image '10421.jpg' uploaded to Google Cloud Storage: image_data/10421.jpg. Count: 47
# Image '12113.jpg' uploaded to Google Cloud Storage: image_data/12113.jpg. Count: 48
# Image '15131.jpg' uploaded to Google Cloud Storage: image_data/15131.jpg. Count: 49
# Image '12628.jpg' uploaded to Google Cloud Storage: image_data/12628.jpg. Count: 50
# Image '16876.jpg' uploaded to Google Cloud Storage: image_data/16876.jpg. Count: 51
# Image '15936.jpg' uploaded to Google Cloud Storage: image_data/15936.jpg. Count: 52
# Image '13009.jpg' uploaded to Google Cloud Storage: image_data/13009.jpg. Count: 53
# Image '15423.jpg' uploaded to Google Cloud Storage: image_data/15423.jpg. Count: 54
# Image '15838.jpg' uploaded to Google Cloud Storage: image_data/15838.jpg. Count: 55
# Image '15304.jpg' uploaded to Google Cloud Storage: image_data/15304.jpg. Count: 56
# Image '15827.jpg' uploaded to Google Cloud Storage: image_data/15827.jpg. Count: 57
# Image '15632.jpg' uploaded to Google Cloud Storage: image_data/15632.jpg. Count: 58
# Image '13824.jpg' uploaded to Google Cloud Storage: image_data/13824.jpg. Count: 59
# Image '12792.jpg' uploaded to Google Cloud Storage: image_data/12792.jpg. Count: 60
# Image '15873.jpg' uploaded to Google Cloud Storage: image_data/15873.jpg. Count: 61
# Image '17511.jpg' uploaded to Google Cloud Storage: image_data/17511.jpg. Count: 62
# Image '17878.jpg' uploaded to Google Cloud Storage: image_data/17878.jpg. Count: 63
# Image '16813.jpg' uploaded to Google Cloud Storage: image_data/16813.jpg. Count: 64
# Image '15934.jpg' uploaded to Google Cloud Storage: image_data/15934.jpg. Count: 65
# Image '11060.jpg' uploaded to Google Cloud Storage: image_data/11060.jpg. Count: 66
# Image '11417.jpg' uploaded to Google Cloud Storage: image_data/11417.jpg. Count: 67
# Image '12414.jpg' uploaded to Google Cloud Storage: image_data/12414.jpg. Count: 68
# Image '12095.jpg' uploaded to Google Cloud Storage: image_data/12095.jpg. Count: 69
# Image '14344.jpg' uploaded to Google Cloud Storage: image_data/14344.jpg. Count: 70
# Image '16797.jpg' uploaded to Google Cloud Storage: image_data/16797.jpg. Count: 71
# Image '11979.jpg' uploaded to Google Cloud Storage: image_data/11979.jpg. Count: 72
# Image '10871.jpg' uploaded to Google Cloud Storage: image_data/10871.jpg. Count: 73
# Image '10011.jpg' uploaded to Google Cloud Storage: image_data/10011.jpg. Count: 74
# Image '17334.jpg' uploaded to Google Cloud Storage: image_data/17334.jpg. Count: 75
# Image '12409.jpg' uploaded to Google Cloud Storage: image_data/12409.jpg. Count: 76
# Image '17662.jpg' uploaded to Google Cloud Storage: image_data/17662.jpg. Count: 77
# Image '10518.jpg' uploaded to Google Cloud Storage: image_data/10518.jpg. Count: 78
# Image '12682.jpg' uploaded to Google Cloud Storage: image_data/12682.jpg. Count: 79
# Image '12505.jpg' uploaded to Google Cloud Storage: image_data/12505.jpg. Count: 80
# Image '17286.jpg' uploaded to Google Cloud Storage: image_data/17286.jpg. Count: 81
# Image '17930.jpg' uploaded to Google Cloud Storage: image_data/17930.jpg. Count: 82
# Image '11766.jpg' uploaded to Google Cloud Storage: image_data/11766.jpg. Count: 83
# Image '17010.jpg' uploaded to Google Cloud Storage: image_data/17010.jpg. Count: 84
# Image '15534.jpg' uploaded to Google Cloud Storage: image_data/15534.jpg. Count: 85
# Image '12487.jpg' uploaded to Google Cloud Storage: image_data/12487.jpg. Count: 86
# Image '12184.jpg' uploaded to Google Cloud Storage: image_data/12184.jpg. Count: 87
# Image '10420.jpg' uploaded to Google Cloud Storage: image_data/10420.jpg. Count: 88
# Image '14665.jpg' uploaded to Google Cloud Storage: image_data/14665.jpg. Count: 89
# Image '12974.jpg' uploaded to Google Cloud Storage: image_data/12974.jpg. Count: 90
# Image '17291.jpg' uploaded to Google Cloud Storage: image_data/17291.jpg. Count: 91
# Image '10473.jpg' uploaded to Google Cloud Storage: image_data/10473.jpg. Count: 92
# Image '13117.jpg' uploaded to Google Cloud Storage: image_data/13117.jpg. Count: 93
# Image '15232.jpg' uploaded to Google Cloud Storage: image_data/15232.jpg. Count: 94
# Image '10772.jpg' uploaded to Google Cloud Storage: image_data/10772.jpg. Count: 95
# Image '12596.jpg' uploaded to Google Cloud Storage: image_data/12596.jpg. Count: 96
# Image '12741.jpg' uploaded to Google Cloud Storage: image_data/12741.jpg. Count: 97
# Image '15196.jpg' uploaded to Google Cloud Storage: image_data/15196.jpg. Count: 98
# Image '10411.jpg' uploaded to Google Cloud Storage: image_data/10411.jpg. Count: 99
# Image '13254.jpg' uploaded to Google Cloud Storage: image_data/13254.jpg. Count: 100
# Image '16617.jpg' uploaded to Google Cloud Storage: image_data/16617.jpg. Count: 101
# Image '13393.jpg' uploaded to Google Cloud Storage: image_data/13393.jpg. Count: 102
# Image '13314.jpg' uploaded to Google Cloud Storage: image_data/13314.jpg. Count: 103
# Image '12332.jpg' uploaded to Google Cloud Storage: image_data/12332.jpg. Count: 104
# Image '18072.jpg' uploaded to Google Cloud Storage: image_data/18072.jpg. Count: 105
# Image '16714.jpg' uploaded to Google Cloud Storage: image_data/16714.jpg. Count: 106
# Image '17922.jpg' uploaded to Google Cloud Storage: image_data/17922.jpg. Count: 107
# Image '14295.jpg' uploaded to Google Cloud Storage: image_data/14295.jpg. Count: 108
# Image '15972.jpg' uploaded to Google Cloud Storage: image_data/15972.jpg. Count: 109
# Image '14723.jpg' uploaded to Google Cloud Storage: image_data/14723.jpg. Count: 110
# Image '15867.jpg' uploaded to Google Cloud Storage: image_data/15867.jpg. Count: 111
# Image '13607.jpg' uploaded to Google Cloud Storage: image_data/13607.jpg. Count: 112
# Image '15068.jpg' uploaded to Google Cloud Storage: image_data/15068.jpg. Count: 113
# Image '11795.jpg' uploaded to Google Cloud Storage: image_data/11795.jpg. Count: 114
# Image '17049.jpg' uploaded to Google Cloud Storage: image_data/17049.jpg. Count: 115
# Image '12216.jpg' uploaded to Google Cloud Storage: image_data/12216.jpg. Count: 116
# Image '13359.jpg' uploaded to Google Cloud Storage: image_data/13359.jpg. Count: 117
# Image '13345.jpg' uploaded to Google Cloud Storage: image_data/13345.jpg. Count: 118
# Image '14519.jpg' uploaded to Google Cloud Storage: image_data/14519.jpg. Count: 405
# Image '16736.jpg' uploaded to Google Cloud Storage: image_data/16736.jpg. Count: 406
# Image '10713.jpg' uploaded to Google Cloud Storage: image_data/10713.jpg. Count: 407
# Image '11911.jpg' uploaded to Google Cloud Storage: image_data/11911.jpg. Count: 408
# Image '15315.jpg' uploaded to Google Cloud Storage: image_data/15315.jpg. Count: 409
# Image '15968.jpg' uploaded to Google Cloud Storage: image_data/15968.jpg. Count: 410
# Image '10383.jpg' uploaded to Google Cloud Storage: image_data/10383.jpg. Count: 411
# Image '10539.jpg' uploaded to Google Cloud Storage: image_data/10539.jpg. Count: 412
# Image '15073.jpg' uploaded to Google Cloud Storage: image_data/15073.jpg. Count: 413
# Image '12212.jpg' uploaded to Google Cloud Storage: image_data/12212.jpg. Count: 414
# Image '14610.jpg' uploaded to Google Cloud Storage: image_data/14610.jpg. Count: 415
# Image '10673.jpg' uploaded to Google Cloud Storage: image_data/10673.jpg. Count: 416
# Image '12568.jpg' uploaded to Google Cloud Storage: image_data/12568.jpg. Count: 417
# Image '13300.jpg' uploaded to Google Cloud Storage: image_data/13300.jpg. Count: 418
# Image '17766.jpg' uploaded to Google Cloud Storage: image_data/17766.jpg. Count: 419
# Image '17061.jpg' uploaded to Google Cloud Storage: image_data/17061.jpg. Count: 420
# Image '14400.jpg' uploaded to Google Cloud Storage: image_data/14400.jpg. Count: 421
# Image '12615.jpg' uploaded to Google Cloud Storage: image_data/12615.jpg. Count: 422
# Image '15801.jpg' uploaded to Google Cloud Storage: image_data/15801.jpg. Count: 423
# Image '10803.jpg' uploaded to Google Cloud Storage: image_data/10803.jpg. Count: 424
# Image '10090.jpg' uploaded to Google Cloud Storage: image_data/10090.jpg. Count: 425
# Image '17069.jpg' uploaded to Google Cloud Storage: image_data/17069.jpg. Count: 426
# Image '16708.jpg' uploaded to Google Cloud Storage: image_data/16708.jpg. Count: 427
# Image '10333.jpg' uploaded to Google Cloud Storage: image_data/10333.jpg. Count: 428
# Image '12645.jpg' uploaded to Google Cloud Storage: image_data/12645.jpg. Count: 429
# Image '13338.jpg' uploaded to Google Cloud Storage: image_data/13338.jpg. Count: 430
# Image '15723.jpg' uploaded to Google Cloud Storage: image_data/15723.jpg. Count: 431
# Image '11863.jpg' uploaded to Google Cloud Storage: image_data/11863.jpg. Count: 432
# Image '16970.jpg' uploaded to Google Cloud Storage: image_data/16970.jpg. Count: 433
# Image '17464.jpg' uploaded to Google Cloud Storage: image_data/17464.jpg. Count: 434
# Image '16040.jpg' uploaded to Google Cloud Storage: image_data/16040.jpg. Count: 435
# Image '12348.jpg' uploaded to Google Cloud Storage: image_data/12348.jpg. Count: 436
# Image '17090.jpg' uploaded to Google Cloud Storage: image_data/17090.jpg. Count: 437
# Image '12610.jpg' uploaded to Google Cloud Storage: image_data/12610.jpg. Count: 438
# Image '13498.jpg' uploaded to Google Cloud Storage: image_data/13498.jpg. Count: 439
# Image '13582.jpg' uploaded to Google Cloud Storage: image_data/13582.jpg. Count: 440
# Image '16981.jpg' uploaded to Google Cloud Storage: image_data/16981.jpg. Count: 512
# Image '12895.jpg' uploaded to Google Cloud Storage: image_data/12895.jpg. Count: 513
# Image '16871.jpg' uploaded to Google Cloud Storage: image_data/16871.jpg. Count: 514
# Image '15573.jpg' uploaded to Google Cloud Storage: image_data/15573.jpg. Count: 515
# Image '12314.jpg' uploaded to Google Cloud Storage: image_data/12314.jpg. Count: 516
# Image '14485.jpg' uploaded to Google Cloud Storage: image_data/14485.jpg. Count: 517
# Image '15223.jpg' uploaded to Google Cloud Storage: image_data/15223.jpg. Count: 518
# Image '15265.jpg' uploaded to Google Cloud Storage: image_data/15265.jpg. Count: 519
# Image '15557.jpg' uploaded to Google Cloud Storage: image_data/15557.jpg. Count: 520
# Image '13540.jpg' uploaded to Google Cloud Storage: image_data/13540.jpg. Count: 521
# Image '10706.jpg' uploaded to Google Cloud Storage: image_data/10706.jpg. Count: 522
# Image '10222.jpg' uploaded to Google Cloud Storage: image_data/10222.jpg. Count: 523
# Image '11331.jpg' uploaded to Google Cloud Storage: image_data/11331.jpg. Count: 524
# Image '18154.jpg' uploaded to Google Cloud Storage: image_data/18154.jpg. Count: 525
# Image '11927.jpg' uploaded to Google Cloud Storage: image_data/11927.jpg. Count: 526
# Image '14806.jpg' uploaded to Google Cloud Storage: image_data/14806.jpg. Count: 527
# Image '11418.jpg' uploaded to Google Cloud Storage: image_data/11418.jpg. Count: 528
# Image '13682.jpg' uploaded to Google Cloud Storage: image_data/13682.jpg. Count: 529
# Image '14639.jpg' uploaded to Google Cloud Storage: image_data/14639.jpg. Count: 530
# Image '14452.jpg' uploaded to Google Cloud Storage: image_data/14452.jpg. Count: 531
# Image '13039.jpg' uploaded to Google Cloud Storage: image_data/13039.jpg. Count: 532
# Image '10299.jpg' uploaded to Google Cloud Storage: image_data/10299.jpg. Count: 533
# Image '17644.jpg' uploaded to Google Cloud Storage: image_data/17644.jpg. Count: 534
# Image '13235.jpg' uploaded to Google Cloud Storage: image_data/13235.jpg. Count: 535
# Image '16780.jpg' uploaded to Google Cloud Storage: image_data/16780.jpg. Count: 536
# Image '13589.jpg' uploaded to Google Cloud Storage: image_data/13589.jpg. Count: 537
# Image '10382.jpg' uploaded to Google Cloud Storage: image_data/10382.jpg. Count: 538
# Image '18089.jpg' uploaded to Google Cloud Storage: image_data/18089.jpg. Count: 539
# Image '10866.jpg' uploaded to Google Cloud Storage: image_data/10866.jpg. Count: 540
# Image '10936.jpg' uploaded to Google Cloud Storage: image_data/10936.jpg. Count: 541
# Image '17814.jpg' uploaded to Google Cloud Storage: image_data/17814.jpg. Count: 542
# Image '18109.jpg' uploaded to Google Cloud Storage: image_data/18109.jpg. Count: 543
# Image '17250.jpg' uploaded to Google Cloud Storage: image_data/17250.jpg. Count: 544
# Image '10630.jpg' uploaded to Google Cloud Storage: image_data/10630.jpg. Count: 545
# Image '17926.jpg' uploaded to Google Cloud Storage: image_data/17926.jpg. Count: 546
# Image '16359.jpg' uploaded to Google Cloud Storage: image_data/16359.jpg. Count: 547
# Image '16151.jpg' uploaded to Google Cloud Storage: image_data/16151.jpg. Count: 548
# Image '14924.jpg' uploaded to Google Cloud Storage: image_data/14924.jpg. Count: 549
# Image '16461.jpg' uploaded to Google Cloud Storage: image_data/16461.jpg. Count: 550
# Image '15430.jpg' uploaded to Google Cloud Storage: image_data/15430.jpg. Count: 551
# Image '16364.jpg' uploaded to Google Cloud Storage: image_data/16364.jpg. Count: 552
# Image '12602.jpg' uploaded to Google Cloud Storage: image_data/12602.jpg. Count: 553
# Image '17230.jpg' uploaded to Google Cloud Storage: image_data/17230.jpg. Count: 554
# Image '17143.jpg' uploaded to Google Cloud Storage: image_data/17143.jpg. Count: 555
# Image '14512.jpg' uploaded to Google Cloud Storage: image_data/14512.jpg. Count: 556
# Image '14486.jpg' uploaded to Google Cloud Storage: image_data/14486.jpg. Count: 557
# Image '13394.jpg' uploaded to Google Cloud Storage: image_data/13394.jpg. Count: 558
# Image '16138.jpg' uploaded to Google Cloud Storage: image_data/16138.jpg. Count: 559
# Image '12914.jpg' uploaded to Google Cloud Storage: image_data/12914.jpg. Count: 560
# Image '12086.jpg' uploaded to Google Cloud Storage: image_data/12086.jpg. Count: 561
# Image '14756.jpg' uploaded to Google Cloud Storage: image_data/14756.jpg. Count: 562
# Image '13908.jpg' uploaded to Google Cloud Storage: image_data/13908.jpg. Count: 563
# Image '12242.jpg' uploaded to Google Cloud Storage: image_data/12242.jpg. Count: 564
# Image '14660.jpg' uploaded to Google Cloud Storage: image_data/14660.jpg. Count: 565
# ...
# Image '12993.jpg' uploaded to Google Cloud Storage: image_data/12993.jpg. Count: 5549
# Image '10465.jpg' uploaded to Google Cloud Storage: image_data/10465.jpg. Count: 5550
# Image '11983.jpg' uploaded to Google Cloud Storage: image_data/11983.jpg. Count: 5551
# Image '15708.jpg' uploaded to Google Cloud Storage: image_data/15708.jpg. Count: 5552
# Image '12021.jpg' uploaded to Google Cloud Storage: image_data/12021.jpg. Count: 5553
# Image '14674.jpg' uploaded to Google Cloud Storage: image_data/14674.jpg. Count: 5554
# Image '12421.jpg' uploaded to Google Cloud Storage: image_data/12421.jpg. Count: 5555
# Image '13605.jpg' uploaded to Google Cloud Storage: image_data/13605.jpg. Count: 5556
# Image '15819.jpg' uploaded to Google Cloud Storage: image_data/15819.jpg. Count: 5557
# Image '12843.jpg' uploaded to Google Cloud Storage: image_data/12843.jpg. Count: 5558
# Image '11783.jpg' uploaded to Google Cloud Storage: image_data/11783.jpg. Count: 5559
# Image '15224.jpg' uploaded to Google Cloud Storage: image_data/15224.jpg. Count: 5560
# Image '12307.jpg' uploaded to Google Cloud Storage: image_data/12307.jpg. Count: 5561
# Image '12882.jpg' uploaded to Google Cloud Storage: image_data/12882.jpg. Count: 5562
# Image '10524.jpg' uploaded to Google Cloud Storage: image_data/10524.jpg. Count: 5563
# Image '11073.jpg' uploaded to Google Cloud Storage: image_data/11073.jpg. Count: 5564
# Image '17806.jpg' uploaded to Google Cloud Storage: image_data/17806.jpg. Count: 5565
# Image '14958.jpg' uploaded to Google Cloud Storage: image_data/14958.jpg. Count: 5566
# Image '15036.jpg' uploaded to Google Cloud Storage: image_data/15036.jpg. Count: 5567
# Image '11243.jpg' uploaded to Google Cloud Storage: image_data/11243.jpg. Count: 5568
# Image '17042.jpg' uploaded to Google Cloud Storage: image_data/17042.jpg. Count: 5569
# Image '15118.jpg' uploaded to Google Cloud Storage: image_data/15118.jpg. Count: 5570
# Image '15027.jpg' uploaded to Google Cloud Storage: image_data/15027.jpg. Count: 5571
# Image '17817.jpg' uploaded to Google Cloud Storage: image_data/17817.jpg. Count: 5572
# Image '10780.jpg' uploaded to Google Cloud Storage: image_data/10780.jpg. Count: 5573
# Image '13843.jpg' uploaded to Google Cloud Storage: image_data/13843.jpg. Count: 5574
# Image '11530.jpg' uploaded to Google Cloud Storage: image_data/11530.jpg. Count: 5575
# Image '18036.jpg' uploaded to Google Cloud Storage: image_data/18036.jpg. Count: 5576
# Image '17263.jpg' uploaded to Google Cloud Storage: image_data/17263.jpg. Count: 5577
# Image '15439.jpg' uploaded to Google Cloud Storage: image_data/15439.jpg. Count: 5578
# Image '17409.jpg' uploaded to Google Cloud Storage: image_data/17409.jpg. Count: 5579
# Image '13519.jpg' uploaded to Google Cloud Storage: image_data/13519.jpg. Count: 5580
# Image '17540.jpg' uploaded to Google Cloud Storage: image_data/17540.jpg. Count: 5581
# Image '16144.jpg' uploaded to Google Cloud Storage: image_data/16144.jpg. Count: 5582
# Image '15497.jpg' uploaded to Google Cloud Storage: image_data/15497.jpg. Count: 5583
# Image '15379.jpg' uploaded to Google Cloud Storage: image_data/15379.jpg. Count: 5584
# Image '11194.jpg' uploaded to Google Cloud Storage: image_data/11194.jpg. Count: 5585
# Image '10487.jpg' uploaded to Google Cloud Storage: image_data/10487.jpg. Count: 5586
# Image '17634.jpg' uploaded to Google Cloud Storage: image_data/17634.jpg. Count: 5587
# Image '12794.jpg' uploaded to Google Cloud Storage: image_data/12794.jpg. Count: 5588
# Image '16467.jpg' uploaded to Google Cloud Storage: image_data/16467.jpg. Count: 5589
# Image '13878.jpg' uploaded to Google Cloud Storage: image_data/13878.jpg. Count: 5590
# Image '10686.jpg' uploaded to Google Cloud Storage: image_data/10686.jpg. Count: 5591
# Image '13882.jpg' uploaded to Google Cloud Storage: image_data/13882.jpg. Count: 5592
# Image '10076.jpg' uploaded to Google Cloud Storage: image_data/10076.jpg. Count: 5593
# Image '11357.jpg' uploaded to Google Cloud Storage: image_data/11357.jpg. Count: 5594
# Image '11078.jpg' uploaded to Google Cloud Storage: image_data/11078.jpg. Count: 5595
# Image '17046.jpg' uploaded to Google Cloud Storage: image_data/17046.jpg. Count: 5596
# Image '14438.jpg' uploaded to Google Cloud Storage: image_data/14438.jpg. Count: 5597
# Image '13154.jpg' uploaded to Google Cloud Storage: image_data/13154.jpg. Count: 5598
# Image '15650.jpg' uploaded to Google Cloud Storage: image_data/15650.jpg. Count: 5599
# Image '16870.jpg' uploaded to Google Cloud Storage: image_data/16870.jpg. Count: 5600
# Image '10286.jpg' uploaded to Google Cloud Storage: image_data/10286.jpg. Count: 5601
# Image '14530.jpg' uploaded to Google Cloud Storage: image_data/14530.jpg. Count: 5602
# Image '13570.jpg' uploaded to Google Cloud Storage: image_data/13570.jpg. Count: 5603
# Image '13205.jpg' uploaded to Google Cloud Storage: image_data/13205.jpg. Count: 5604
# Image '16567.jpg' uploaded to Google Cloud Storage: image_data/16567.jpg. Count: 5605
# Image '11962.jpg' uploaded to Google Cloud Storage: image_data/11962.jpg. Count: 5606
# Image '16318.jpg' uploaded to Google Cloud Storage: image_data/16318.jpg. Count: 5607
# Image '13743.jpg' uploaded to Google Cloud Storage: image_data/13743.jpg. Count: 5608
# Image '12064.jpg' uploaded to Google Cloud Storage: image_data/12064.jpg. Count: 5609
# Image '10976.jpg' uploaded to Google Cloud Storage: image_data/10976.jpg. Count: 5610
# Image '17908.jpg' uploaded to Google Cloud Storage: image_data/17908.jpg. Count: 5611
# Image '15242.jpg' uploaded to Google Cloud Storage: image_data/15242.jpg. Count: 5612
# Image '10045.jpg' uploaded to Google Cloud Storage: image_data/10045.jpg. Count: 5613
# Image '10600.jpg' uploaded to Google Cloud Storage: image_data/10600.jpg. Count: 5614
# Image '13799.jpg' uploaded to Google Cloud Storage: image_data/13799.jpg. Count: 5615
# Image '16900.jpg' uploaded to Google Cloud Storage: image_data/16900.jpg. Count: 5616
# Image '15588.jpg' uploaded to Google Cloud Storage: image_data/15588.jpg. Count: 5617
# Image '14763.jpg' uploaded to Google Cloud Storage: image_data/14763.jpg. Count: 5618
# Image '11155.jpg' uploaded to Google Cloud Storage: image_data/11155.jpg. Count: 5619
# Image '12101.jpg' uploaded to Google Cloud Storage: image_data/12101.jpg. Count: 5620
# Image '16683.jpg' uploaded to Google Cloud Storage: image_data/16683.jpg. Count: 5621
# Image '16365.jpg' uploaded to Google Cloud Storage: image_data/16365.jpg. Count: 5622
# Image '11008.jpg' uploaded to Google Cloud Storage: image_data/11008.jpg. Count: 5623
# Image '16731.jpg' uploaded to Google Cloud Storage: image_data/16731.jpg. Count: 5624
# Image '17603.jpg' uploaded to Google Cloud Storage: image_data/17603.jpg. Count: 5625
# Image '12149.jpg' uploaded to Google Cloud Storage: image_data/12149.jpg. Count: 5626
# Image '13000.jpg' uploaded to Google Cloud Storage: image_data/13000.jpg. Count: 5627
# Image '17094.jpg' uploaded to Google Cloud Storage: image_data/17094.jpg. Count: 5628
# Image '12050.jpg' uploaded to Google Cloud Storage: image_data/12050.jpg. Count: 5629
# Image '12513.jpg' uploaded to Google Cloud Storage: image_data/12513.jpg. Count: 5630
# Image '12760.jpg' uploaded to Google Cloud Storage: image_data/12760.jpg. Count: 5631
# Image '14669.jpg' uploaded to Google Cloud Storage: image_data/14669.jpg. Count: 5632
# Image '11163.jpg' uploaded to Google Cloud Storage: image_data/11163.jpg. Count: 5633
# Image '11526.jpg' uploaded to Google Cloud Storage: image_data/11526.jpg. Count: 5634
# Image '12276.jpg' uploaded to Google Cloud Storage: image_data/12276.jpg. Count: 5635
# Image '13913.jpg' uploaded to Google Cloud Storage: image_data/13913.jpg. Count: 5636
# Image '13396.jpg' uploaded to Google Cloud Storage: image_data/13396.jpg. Count: 5637
# Image '14160.jpg' uploaded to Google Cloud Storage: image_data/14160.jpg. Count: 5638
# Image '12519.jpg' uploaded to Google Cloud Storage: image_data/12519.jpg. Count: 5639
# Image '10119.jpg' uploaded to Google Cloud Storage: image_data/10119.jpg. Count: 5640
# Image '17940.jpg' uploaded to Google Cloud Storage: image_data/17940.jpg. Count: 5641
# Image '13894.jpg' uploaded to Google Cloud Storage: image_data/13894.jpg. Count: 5642
# Image '16553.jpg' uploaded to Google Cloud Storage: image_data/16553.jpg. Count: 5643
# Image '11499.jpg' uploaded to Google Cloud Storage: image_data/11499.jpg. Count: 5644
# Image '16292.jpg' uploaded to Google Cloud Storage: image_data/16292.jpg. Count: 5645
# Image '13327.jpg' uploaded to Google Cloud Storage: image_data/13327.jpg. Count: 5646
# Image '14971.jpg' uploaded to Google Cloud Storage: image_data/14971.jpg. Count: 5647
# Image '14394.jpg' uploaded to Google Cloud Storage: image_data/14394.jpg. Count: 5648
# Image '17655.jpg' uploaded to Google Cloud Storage: image_data/17655.jpg. Count: 5649
# Image '15128.jpg' uploaded to Google Cloud Storage: image_data/15128.jpg. Count: 5650
# Image '16312.jpg' uploaded to Google Cloud Storage: image_data/16312.jpg. Count: 5651
# Image '13293.jpg' uploaded to Google Cloud Storage: image_data/13293.jpg. Count: 5652
# Image '17395.jpg' uploaded to Google Cloud Storage: image_data/17395.jpg. Count: 5653
# Image '16809.jpg' uploaded to Google Cloud Storage: image_data/16809.jpg. Count: 5654
# Image '17400.jpg' uploaded to Google Cloud Storage: image_data/17400.jpg. Count: 5655
# Image '10258.jpg' uploaded to Google Cloud Storage: image_data/10258.jpg. Count: 5656
# Image '12986.jpg' uploaded to Google Cloud Storage: image_data/12986.jpg. Count: 5657
# Image '10868.jpg' uploaded to Google Cloud Storage: image_data/10868.jpg. Count: 5658
# Image '12629.jpg' uploaded to Google Cloud Storage: image_data/12629.jpg. Count: 5659
# Image '13334.jpg' uploaded to Google Cloud Storage: image_data/13334.jpg. Count: 5660
# Image '12344.jpg' uploaded to Google Cloud Storage: image_data/12344.jpg. Count: 5661
# Image '16373.jpg' uploaded to Google Cloud Storage: image_data/16373.jpg. Count: 5662
# Image '13618.jpg' uploaded to Google Cloud Storage: image_data/13618.jpg. Count: 5663
# Image '11397.jpg' uploaded to Google Cloud Storage: image_data/11397.jpg. Count: 5664
# Image '14275.jpg' uploaded to Google Cloud Storage: image_data/14275.jpg. Count: 5665
# Image '11062.jpg' uploaded to Google Cloud Storage: image_data/11062.jpg. Count: 5666
# Image '14765.jpg' uploaded to Google Cloud Storage: image_data/14765.jpg. Count: 5667
# Image '16087.jpg' uploaded to Google Cloud Storage: image_data/16087.jpg. Count: 5668
# Image '12804.jpg' uploaded to Google Cloud Storage: image_data/12804.jpg. Count: 5669
# Image '13637.jpg' uploaded to Google Cloud Storage: image_data/13637.jpg. Count: 5670
# Image '15863.jpg' uploaded to Google Cloud Storage: image_data/15863.jpg. Count: 5671
# Image '13752.jpg' uploaded to Google Cloud Storage: image_data/13752.jpg. Count: 5672
# Image '16938.jpg' uploaded to Google Cloud Storage: image_data/16938.jpg. Count: 5673
# Image '11169.jpg' uploaded to Google Cloud Storage: image_data/11169.jpg. Count: 5674
# Image '15421.jpg' uploaded to Google Cloud Storage: image_data/15421.jpg. Count: 5675
# Image '13115.jpg' uploaded to Google Cloud Storage: image_data/13115.jpg. Count: 5676
# Image '17165.jpg' uploaded to Google Cloud Storage: image_data/17165.jpg. Count: 5677
# Image '12976.jpg' uploaded to Google Cloud Storage: image_data/12976.jpg. Count: 5678
# Image '15711.jpg' uploaded to Google Cloud Storage: image_data/15711.jpg. Count: 5679
# Image '13641.jpg' uploaded to Google Cloud Storage: image_data/13641.jpg. Count: 5680
# Image '15142.jpg' uploaded to Google Cloud Storage: image_data/15142.jpg. Count: 5681
# Image '15796.jpg' uploaded to Google Cloud Storage: image_data/15796.jpg. Count: 5682
# Image '10397.jpg' uploaded to Google Cloud Storage: image_data/10397.jpg. Count: 5683
# Image '14165.jpg' uploaded to Google Cloud Storage: image_data/14165.jpg. Count: 5684
# Image '14478.jpg' uploaded to Google Cloud Storage: image_data/14478.jpg. Count: 5685
# Image '17658.jpg' uploaded to Google Cloud Storage: image_data/17658.jpg. Count: 5686
# Image '14391.jpg' uploaded to Google Cloud Storage: image_data/14391.jpg. Count: 5687
# Image '12347.jpg' uploaded to Google Cloud Storage: image_data/12347.jpg. Count: 5688
# Image '13724.jpg' uploaded to Google Cloud Storage: image_data/13724.jpg. Count: 5689
# Image '17174.jpg' uploaded to Google Cloud Storage: image_data/17174.jpg. Count: 5690
# Image '16628.jpg' uploaded to Google Cloud Storage: image_data/16628.jpg. Count: 5691
# Image '13719.jpg' uploaded to Google Cloud Storage: image_data/13719.jpg. Count: 5692
# Image '14884.jpg' uploaded to Google Cloud Storage: image_data/14884.jpg. Count: 5693
# Image '13382.jpg' uploaded to Google Cloud Storage: image_data/13382.jpg. Count: 5694
# Image '15000.jpg' uploaded to Google Cloud Storage: image_data/15000.jpg. Count: 5695
# Image '13836.jpg' uploaded to Google Cloud Storage: image_data/13836.jpg. Count: 5696
# Image '18194.jpg' uploaded to Google Cloud Storage: image_data/18194.jpg. Count: 5697
# Image '17375.jpg' uploaded to Google Cloud Storage: image_data/17375.jpg. Count: 5698
# Image '14889.jpg' uploaded to Google Cloud Storage: image_data/14889.jpg. Count: 5699
# Image '16521.jpg' uploaded to Google Cloud Storage: image_data/16521.jpg. Count: 5700
# Image '10169.jpg' uploaded to Google Cloud Storage: image_data/10169.jpg. Count: 5701
# Image '13654.jpg' uploaded to Google Cloud Storage: image_data/13654.jpg. Count: 5702
# Image '11007.jpg' uploaded to Google Cloud Storage: image_data/11007.jpg. Count: 5703
# Image '12478.jpg' uploaded to Google Cloud Storage: image_data/12478.jpg. Count: 5704
# Image '13791.jpg' uploaded to Google Cloud Storage: image_data/13791.jpg. Count: 5705
# Image '12457.jpg' uploaded to Google Cloud Storage: image_data/12457.jpg. Count: 5706
# Image '17115.jpg' uploaded to Google Cloud Storage: image_data/17115.jpg. Count: 5707
# Image '11306.jpg' uploaded to Google Cloud Storage: image_data/11306.jpg. Count: 5708
# Image '11636.jpg' uploaded to Google Cloud Storage: image_data/11636.jpg. Count: 5709
# Image '10207.jpg' uploaded to Google Cloud Storage: image_data/10207.jpg. Count: 5710
# Image '18090.jpg' uploaded to Google Cloud Storage: image_data/18090.jpg. Count: 5711
# Image '10758.jpg' uploaded to Google Cloud Storage: image_data/10758.jpg. Count: 5712
# Image '11937.jpg' uploaded to Google Cloud Storage: image_data/11937.jpg. Count: 5713
# Image '10677.jpg' uploaded to Google Cloud Storage: image_data/10677.jpg. Count: 5714
# Image '11802.jpg' uploaded to Google Cloud Storage: image_data/11802.jpg. Count: 5715
# Image '16244.jpg' uploaded to Google Cloud Storage: image_data/16244.jpg. Count: 5716
# Image '14365.jpg' uploaded to Google Cloud Storage: image_data/14365.jpg. Count: 5717
# Image '17243.jpg' uploaded to Google Cloud Storage: image_data/17243.jpg. Count: 5718
# Image '17645.jpg' uploaded to Google Cloud Storage: image_data/17645.jpg. Count: 5719
# Image '11734.jpg' uploaded to Google Cloud Storage: image_data/11734.jpg. Count: 5720
# Image '11245.jpg' uploaded to Google Cloud Storage: image_data/11245.jpg. Count: 5721
# Image '12448.jpg' uploaded to Google Cloud Storage: image_data/12448.jpg. Count: 5722
# Image '11046.jpg' uploaded to Google Cloud Storage: image_data/11046.jpg. Count: 5723
# Image '14177.jpg' uploaded to Google Cloud Storage: image_data/14177.jpg. Count: 5724
# Image '12295.jpg' uploaded to Google Cloud Storage: image_data/12295.jpg. Count: 5725
# Image '11520.jpg' uploaded to Google Cloud Storage: image_data/11520.jpg. Count: 5726
# Image '10566.jpg' uploaded to Google Cloud Storage: image_data/10566.jpg. Count: 5727
# Image '18174.jpg' uploaded to Google Cloud Storage: image_data/18174.jpg. Count: 5728
# Image '14595.jpg' uploaded to Google Cloud Storage: image_data/14595.jpg. Count: 5729
# Image '17043.jpg' uploaded to Google Cloud Storage: image_data/17043.jpg. Count: 5730
# Image '17025.jpg' uploaded to Google Cloud Storage: image_data/17025.jpg. Count: 5731
# Image '15273.jpg' uploaded to Google Cloud Storage: image_data/15273.jpg. Count: 5732
# Image '16347.jpg' uploaded to Google Cloud Storage: image_data/16347.jpg. Count: 5733
# Process finished

# %%
 # List objects in the specified folder path
folder_objects = list(bucket.list_blobs(prefix=destination_directory_images))

# Count the number of objects in the folder
num_objects = len(folder_objects)
print(f"Number of objects in '{destination_directory_images}': {num_objects}")
# Out:
# Number of objects in 'image_data/': 5733

# %%
# Upload the CSV file
csv_name = 'bbox_train.csv'
local_annotations_path = os.path.join(local_directory_annotations, csv_name)
blob = bucket.blob(csv_name)
blob.upload_from_filename(local_annotations_path)
print(f"File '{local_annotations_path}' uploaded to '{csv_name}'.")
# Out:
# File '/home/klingenm/.lewagon/facetally_data/bbox_train.csv' uploaded to 'bbox_train.csv'.

# %% [markdown]
# # Download data from BigQuery if it doesn't exist locally

# %%
def download_images_from_GCP(bucket_name, folder_path, destination_folder, overwrite = False):

    # Boolean to control if anything has been downloaded
    changes = False

    # Initialize the Cloud Storage client
    storage_client = storage.Client()

    # Get the bucket
    bucket = storage_client.bucket(bucket_name)

    # List objects in the specified folder path
    folder_objects = bucket.list_blobs(prefix=folder_path)

    # Create a local folder if it doesn't exist
    os.makedirs(destination_folder, exist_ok=True)

    # Download each image file from the folder
    for obj in folder_objects:
        # Construct local file path for downloading
        local_file_path = os.path.join(destination_folder, os.path.basename(obj.name))
        # Check if the file exists locally
        if overwrite or not os.path.exists(local_file_path):
            # Download the object to the local file
            obj.download_to_filename(local_file_path)
            print(f"Downloaded '{obj.name}' to '{local_file_path}'.")
            changes = True

    return changes

# %%
# Lirectories path
local_image_folder = os.path.join(LOCAL_DATA_PATH, 'raw_data', 'image_data')
local_annot_folder = os.path.join(LOCAL_DATA_PATH, 'raw_data')

# Bucket paths
bucket_image_folder = 'image_data/'  # Destination folder in the bucket
csv_name = 'bbox_train.csv'

# %%
print('Updating local raw data from Google Cloud Storage...')
changes_csv = download_images_from_GCP(BUCKET_NAME, csv_name, local_annot_folder)
changes_images = download_images_from_GCP(BUCKET_NAME, bucket_image_folder, local_image_folder)
if not(changes_csv or changes_images):
    print('Local raw data folder is up to date')
# Out:
# Updating local raw data from Google Cloud Storage...
# Downloaded 'image_data/10041.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10041.jpg'.
# Downloaded 'image_data/10042.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10042.jpg'.
# Downloaded 'image_data/10043.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10043.jpg'.
# Downloaded 'image_data/10045.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10045.jpg'.
# Downloaded 'image_data/10046.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10046.jpg'.
# Downloaded 'image_data/10049.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10049.jpg'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb Cell 16 line 9
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> print('Updating local raw data from Google Cloud Storage...')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> changes_csv = download_images_from_GCP(bucket_name, csv_name, local_annot_folder)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> changes_images = download_images_from_GCP(bucket_name, bucket_image_folder, local_image_folder)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> if not(changes_csv or changes_images):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     print('Local raw data folder is up to date')
#
# /home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> # Check if the file exists locally
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> if overwrite or not os.path.exists(local_file_path):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     # Download the object to the local file
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     obj.download_to_filename(local_file_path)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     print(f"Downloaded '{obj.name}' to '{local_file_path}'.")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     changes = True
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:1280, in Blob.download_to_filename(self, filename, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1172 def download_to_filename(
#    1173     self,
#    1174     filename,
#    (...)
#    1187     retry=DEFAULT_RETRY,
#    1188 ):
#    1189     """Download the contents of this blob into a named file.
#    1190
#    1191     If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1277     :raises: :class:`google.cloud.exceptions.NotFound`
#    1278     """
# -> 1280     self._handle_filename_and_download(
#    1281         filename,
#    1282         client=client,
#    1283         start=start,
#    1284         end=end,
#    1285         raw_download=raw_download,
#    1286         if_etag_match=if_etag_match,
#    1287         if_etag_not_match=if_etag_not_match,
#    1288         if_generation_match=if_generation_match,
#    1289         if_generation_not_match=if_generation_not_match,
#    1290         if_metageneration_match=if_metageneration_match,
#    1291         if_metageneration_not_match=if_metageneration_not_match,
#    1292         timeout=timeout,
#    1293         checksum=checksum,
#    1294         retry=retry,
#    1295     )
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:1156, in Blob._handle_filename_and_download(self, filename, *args, **kwargs)
#    1154 try:
#    1155     with open(filename, "wb") as file_obj:
# -> 1156         self._prep_and_do_download(
#    1157             file_obj,
#    1158             *args,
#    1159             **kwargs,
#    1160         )
#    1162 except resumable_media.DataCorruption:
#    1163     # Delete the corrupt downloaded file.
#    1164     os.remove(filename)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:4329, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4326 transport = client._http
#    4328 try:
# -> 4329     self._do_download(
#    4330         transport,
#    4331         file_obj,
#    4332         download_url,
#    4333         headers,
#    4334         start,
#    4335         end,
#    4336         raw_download,
#    4337         timeout=timeout,
#    4338         checksum=checksum,
#    4339         retry=retry,
#    4340     )
#    4341 except resumable_media.InvalidResponse as exc:
#    4342     _raise_from_invalid_response(exc)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:985, in Blob._do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#     976     download = klass(
#     977         download_url,
#     978         stream=file_obj,
#    (...)
#     982         checksum=checksum,
#     983     )
#     984     download._retry_strategy = retry_strategy
# --> 985     response = download.consume(transport, timeout=timeout)
#     986     self._extract_headers_from_download(response)
#     987 else:
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:237, in Download.consume(self, transport, timeout)
#     233         self._write_to_stream(result)
#     235     return result
# --> 237 return _request_helpers.wait_and_retry(
#     238     retriable_request, self._get_status_code, self._retry_strategy
#     239 )
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:233, in Download.consume.<locals>.retriable_request()
#     230             raise Exception(msg) from exc
#     231         self._bytes_downloaded = 0
# --> 233     self._write_to_stream(result)
#     235 return result
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:123, in Download._write_to_stream(self, response)
#     119 local_checksum_object = _add_decoder(response.raw, checksum_object)
#     120 body_iter = response.iter_content(
#     121     chunk_size=_request_helpers._SINGLE_GET_CHUNK_SIZE, decode_unicode=False
#     122 )
# --> 123 for chunk in body_iter:
#     124     self._stream.write(chunk)
#     125     self._bytes_downloaded += len(chunk)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:934, in HTTPResponse.stream(self, amt, decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 934         data = self.read(amt=amt, decode_content=decode_content)
#     936         if data:
#     937             yield data
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:877, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     874     if len(self._decoded_buffer) >= amt:
#     875         return self._decoded_buffer.get(amt)
# --> 877 data = self._raw_read(amt)
#     879 flush_decoder = amt is None or (amt != 0 and not data)
#     881 if not data and len(self._decoded_buffer) == 0:
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:812, in HTTPResponse._raw_read(self, amt)
#     809 fp_closed = getattr(self._fp, "closed", False)
#     811 with self._error_catcher():
# --> 812     data = self._fp_read(amt) if not fp_closed else b""
#     813     if amt is not None and amt != 0 and not data:
#     814         # Platform-specific: Buggy versions of Python.
#     815         # Close the connection when no data is returned
#    (...)
#     820         # not properly close the connection in all cases. There is
#     821         # no harm in redundantly calling close.
#     822         self._fp.close()
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:797, in HTTPResponse._fp_read(self, amt)
#     794     return buffer.getvalue()
#     795 else:
#     796     # StringIO doesn't like amt=None
# --> 797     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
