# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
from google.cloud import storage
# import numpy as np
# from tqdm.auto import tqdm
# from sklearn.model_selection import train_test_split
# from matplotlib import pyplot as plt
# from PIL import Image
# import cv2
# import tensorflow as tf
# from tensorflow import keras
# from keras_cv import bounding_box
# from keras_cv import visualization
# import keras_cv
# import shutil
#os.chdir allows you to change directories, like cd in the Terminal
#os.chdir('/content/drive/MyDrive/LeWagon/Notebook')

# %% [markdown]
# # Load raw data

# %%
# Project path
project_root = os.path.dirname(os.getcwd())

# Directories path
test_image_folder = os.path.join(project_root, 'raw_data', 'image_data')
path_annot = os.path.join(project_root, 'raw_data', 'bbox_train.csv')

# %%
df = pd.read_csv(path_annot)
df.head()
# Out:
#         Name  width  height  xmin  ymin  xmax  ymax
# 0  10001.jpg    612     408   192   199   230   235
# 1  10001.jpg    612     408   247   168   291   211
# 2  10001.jpg    612     408   321   176   366   222
# 3  10001.jpg    612     408   355   183   387   214
# 4  10002.jpg    612     408   339   165   378   202

# %% [markdown]
# # Check which images have anotations. Only those ones are pushed to Google Cloud

# %%
annotated_images_names = df.Name.unique()

# %% [markdown]
# # Load data to Cloud Storage Bucket

# %%
# Create a Storage client
storage_client = storage.Client()

# Set the name of the bucket in Google Cloud Storage
bucket_name = 'raw_data_facetally'

# Get the bucket
bucket = storage_client.bucket(bucket_name)

# Project path
project_root = os.path.dirname(os.getcwd())

# Directories path
local_directory_images = os.path.join(project_root, 'raw_data', 'image_data')
local_directory_annotations = os.path.join(project_root, 'raw_data')

# Destination directory in the bucket
destination_directory_images = 'image_data/'  # Destination folder in the bucket

# Filter images with annotations
raw_images_names = os.listdir(local_directory_images)
filtered_images_names = []
for image in raw_images_names:
    for annotation in annotated_images_names:
        if image == annotation:
            filtered_images_names.append(image)

# %%
# Upload the images
print(f"Uploading images")
for count, filename in enumerate(filtered_images_names):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        local_image_path = os.path.join(local_directory_images, filename)
        destination_blob_name = os.path.join(destination_directory_images, filename)

        # Create a Blob object and upload the image file to the bucket
        blob = bucket.blob(destination_blob_name)
        if blob.exists():
            print(f"The file '{destination_blob_name}' already exists, won't be pushed. Count: {count + 1}")
        else:
            blob.upload_from_filename(local_image_path)
            print(f"Image '{filename}' uploaded to Google Cloud Storage: {destination_blob_name}. Count: {count + 1}")
print(f"Process finished")
# Out:
# Uploading images
# The file 'image_data/15603.jpg' already exists, won't be pushed. Count: 1
# The file 'image_data/13153.jpg' already exists, won't be pushed. Count: 2
# The file 'image_data/12753.jpg' already exists, won't be pushed. Count: 3
# The file 'image_data/15241.jpg' already exists, won't be pushed. Count: 4
# The file 'image_data/10028.jpg' already exists, won't be pushed. Count: 5
# The file 'image_data/16053.jpg' already exists, won't be pushed. Count: 6
# The file 'image_data/17084.jpg' already exists, won't be pushed. Count: 7
# The file 'image_data/16335.jpg' already exists, won't be pushed. Count: 8
# The file 'image_data/16231.jpg' already exists, won't be pushed. Count: 9
# The file 'image_data/14072.jpg' already exists, won't be pushed. Count: 10
# The file 'image_data/16428.jpg' already exists, won't be pushed. Count: 11
# The file 'image_data/17546.jpg' already exists, won't be pushed. Count: 12
# The file 'image_data/17717.jpg' already exists, won't be pushed. Count: 13
# The file 'image_data/13947.jpg' already exists, won't be pushed. Count: 14
# The file 'image_data/11412.jpg' already exists, won't be pushed. Count: 15
# The file 'image_data/13173.jpg' already exists, won't be pushed. Count: 16
# The file 'image_data/11691.jpg' already exists, won't be pushed. Count: 17
# The file 'image_data/13806.jpg' already exists, won't be pushed. Count: 18
# The file 'image_data/17776.jpg' already exists, won't be pushed. Count: 19
# The file 'image_data/10934.jpg' already exists, won't be pushed. Count: 20
# The file 'image_data/16263.jpg' already exists, won't be pushed. Count: 21
# The file 'image_data/17756.jpg' already exists, won't be pushed. Count: 22
# The file 'image_data/16227.jpg' already exists, won't be pushed. Count: 23
# The file 'image_data/12572.jpg' already exists, won't be pushed. Count: 24
# The file 'image_data/15545.jpg' already exists, won't be pushed. Count: 25
# The file 'image_data/16291.jpg' already exists, won't be pushed. Count: 26
# The file 'image_data/11359.jpg' already exists, won't be pushed. Count: 27
# The file 'image_data/14579.jpg' already exists, won't be pushed. Count: 28
# The file 'image_data/10790.jpg' already exists, won't be pushed. Count: 29
# The file 'image_data/13086.jpg' already exists, won't be pushed. Count: 30
# The file 'image_data/10073.jpg' already exists, won't be pushed. Count: 31
# The file 'image_data/15096.jpg' already exists, won't be pushed. Count: 32
# The file 'image_data/14521.jpg' already exists, won't be pushed. Count: 33
# The file 'image_data/16875.jpg' already exists, won't be pushed. Count: 34
# The file 'image_data/11699.jpg' already exists, won't be pushed. Count: 35
# The file 'image_data/17436.jpg' already exists, won't be pushed. Count: 36
# The file 'image_data/14867.jpg' already exists, won't be pushed. Count: 37
# The file 'image_data/11861.jpg' already exists, won't be pushed. Count: 38
# The file 'image_data/16894.jpg' already exists, won't be pushed. Count: 39
# The file 'image_data/17683.jpg' already exists, won't be pushed. Count: 40
# The file 'image_data/15740.jpg' already exists, won't be pushed. Count: 41
# The file 'image_data/17011.jpg' already exists, won't be pushed. Count: 42
# The file 'image_data/10282.jpg' already exists, won't be pushed. Count: 43
# The file 'image_data/15606.jpg' already exists, won't be pushed. Count: 44
# The file 'image_data/13588.jpg' already exists, won't be pushed. Count: 45
# The file 'image_data/14450.jpg' already exists, won't be pushed. Count: 46
# The file 'image_data/10421.jpg' already exists, won't be pushed. Count: 47
# The file 'image_data/12113.jpg' already exists, won't be pushed. Count: 48
# The file 'image_data/15131.jpg' already exists, won't be pushed. Count: 49
# The file 'image_data/12628.jpg' already exists, won't be pushed. Count: 50
# The file 'image_data/16876.jpg' already exists, won't be pushed. Count: 51
# The file 'image_data/15936.jpg' already exists, won't be pushed. Count: 52
# The file 'image_data/13009.jpg' already exists, won't be pushed. Count: 53
# The file 'image_data/15423.jpg' already exists, won't be pushed. Count: 54
# The file 'image_data/15838.jpg' already exists, won't be pushed. Count: 55
# The file 'image_data/15304.jpg' already exists, won't be pushed. Count: 56
# The file 'image_data/15827.jpg' already exists, won't be pushed. Count: 57
# The file 'image_data/15632.jpg' already exists, won't be pushed. Count: 58
# The file 'image_data/13824.jpg' already exists, won't be pushed. Count: 59
# The file 'image_data/12792.jpg' already exists, won't be pushed. Count: 60
# The file 'image_data/15873.jpg' already exists, won't be pushed. Count: 61
# The file 'image_data/17511.jpg' already exists, won't be pushed. Count: 62
# The file 'image_data/17878.jpg' already exists, won't be pushed. Count: 63
# The file 'image_data/16813.jpg' already exists, won't be pushed. Count: 64
# The file 'image_data/15934.jpg' already exists, won't be pushed. Count: 65
# The file 'image_data/11060.jpg' already exists, won't be pushed. Count: 66
# The file 'image_data/11417.jpg' already exists, won't be pushed. Count: 67
# The file 'image_data/12414.jpg' already exists, won't be pushed. Count: 68
# The file 'image_data/12095.jpg' already exists, won't be pushed. Count: 69
# The file 'image_data/14344.jpg' already exists, won't be pushed. Count: 70
# The file 'image_data/16797.jpg' already exists, won't be pushed. Count: 71
# The file 'image_data/11979.jpg' already exists, won't be pushed. Count: 72
# The file 'image_data/10871.jpg' already exists, won't be pushed. Count: 73
# The file 'image_data/10011.jpg' already exists, won't be pushed. Count: 74
# The file 'image_data/17334.jpg' already exists, won't be pushed. Count: 75
# The file 'image_data/12409.jpg' already exists, won't be pushed. Count: 76
# The file 'image_data/17662.jpg' already exists, won't be pushed. Count: 77
# The file 'image_data/10518.jpg' already exists, won't be pushed. Count: 78
# The file 'image_data/12682.jpg' already exists, won't be pushed. Count: 79
# The file 'image_data/12505.jpg' already exists, won't be pushed. Count: 80
# The file 'image_data/17286.jpg' already exists, won't be pushed. Count: 81
# The file 'image_data/17930.jpg' already exists, won't be pushed. Count: 82
# The file 'image_data/11766.jpg' already exists, won't be pushed. Count: 83
# The file 'image_data/17010.jpg' already exists, won't be pushed. Count: 84
# The file 'image_data/15534.jpg' already exists, won't be pushed. Count: 85
# The file 'image_data/12487.jpg' already exists, won't be pushed. Count: 86
# The file 'image_data/12184.jpg' already exists, won't be pushed. Count: 87
# The file 'image_data/10420.jpg' already exists, won't be pushed. Count: 88
# The file 'image_data/14665.jpg' already exists, won't be pushed. Count: 89
# The file 'image_data/12974.jpg' already exists, won't be pushed. Count: 90
# The file 'image_data/17291.jpg' already exists, won't be pushed. Count: 91
# The file 'image_data/10473.jpg' already exists, won't be pushed. Count: 92
# The file 'image_data/13117.jpg' already exists, won't be pushed. Count: 93
# The file 'image_data/15232.jpg' already exists, won't be pushed. Count: 94
# The file 'image_data/10772.jpg' already exists, won't be pushed. Count: 95
# The file 'image_data/12596.jpg' already exists, won't be pushed. Count: 96
# The file 'image_data/12741.jpg' already exists, won't be pushed. Count: 97
# The file 'image_data/15196.jpg' already exists, won't be pushed. Count: 98
# The file 'image_data/10411.jpg' already exists, won't be pushed. Count: 99
# The file 'image_data/13254.jpg' already exists, won't be pushed. Count: 100
# The file 'image_data/16617.jpg' already exists, won't be pushed. Count: 101
# The file 'image_data/13393.jpg' already exists, won't be pushed. Count: 102
# The file 'image_data/13314.jpg' already exists, won't be pushed. Count: 103
# The file 'image_data/12332.jpg' already exists, won't be pushed. Count: 104
# The file 'image_data/18072.jpg' already exists, won't be pushed. Count: 105
# The file 'image_data/16714.jpg' already exists, won't be pushed. Count: 106
# The file 'image_data/17922.jpg' already exists, won't be pushed. Count: 107
# The file 'image_data/14295.jpg' already exists, won't be pushed. Count: 108
# The file 'image_data/15972.jpg' already exists, won't be pushed. Count: 109
# The file 'image_data/14723.jpg' already exists, won't be pushed. Count: 110
# The file 'image_data/15867.jpg' already exists, won't be pushed. Count: 111
# The file 'image_data/13607.jpg' already exists, won't be pushed. Count: 112
# The file 'image_data/15068.jpg' already exists, won't be pushed. Count: 113
# The file 'image_data/11795.jpg' already exists, won't be pushed. Count: 114
# The file 'image_data/17049.jpg' already exists, won't be pushed. Count: 115
# The file 'image_data/12216.jpg' already exists, won't be pushed. Count: 116
# The file 'image_data/13359.jpg' already exists, won't be pushed. Count: 117
# The file 'image_data/13345.jpg' already exists, won't be pushed. Count: 118
# The file 'image_data/13872.jpg' already exists, won't be pushed. Count: 119
# The file 'image_data/14866.jpg' already exists, won't be pushed. Count: 120
# The file 'image_data/16587.jpg' already exists, won't be pushed. Count: 121
# The file 'image_data/13578.jpg' already exists, won't be pushed. Count: 122
# The file 'image_data/16178.jpg' already exists, won't be pushed. Count: 123
# The file 'image_data/16041.jpg' already exists, won't be pushed. Count: 124
# The file 'image_data/11203.jpg' already exists, won't be pushed. Count: 125
# The file 'image_data/12619.jpg' already exists, won't be pushed. Count: 126
# The file 'image_data/14895.jpg' already exists, won't be pushed. Count: 127
# The file 'image_data/10905.jpg' already exists, won't be pushed. Count: 128
# The file 'image_data/16254.jpg' already exists, won't be pushed. Count: 129
# The file 'image_data/13370.jpg' already exists, won't be pushed. Count: 130
# The file 'image_data/17838.jpg' already exists, won't be pushed. Count: 131
# The file 'image_data/12676.jpg' already exists, won't be pushed. Count: 132
# The file 'image_data/16374.jpg' already exists, won't be pushed. Count: 133
# The file 'image_data/15188.jpg' already exists, won't be pushed. Count: 134
# The file 'image_data/14459.jpg' already exists, won't be pushed. Count: 135
# The file 'image_data/11393.jpg' already exists, won't be pushed. Count: 136
# The file 'image_data/11896.jpg' already exists, won't be pushed. Count: 137
# The file 'image_data/11465.jpg' already exists, won't be pushed. Count: 138
# The file 'image_data/10862.jpg' already exists, won't be pushed. Count: 139
# The file 'image_data/18091.jpg' already exists, won't be pushed. Count: 140
# The file 'image_data/15170.jpg' already exists, won't be pushed. Count: 141
# The file 'image_data/11171.jpg' already exists, won't be pushed. Count: 142
# The file 'image_data/15512.jpg' already exists, won't be pushed. Count: 143
# The file 'image_data/17672.jpg' already exists, won't be pushed. Count: 144
# The file 'image_data/10322.jpg' already exists, won't be pushed. Count: 145
# The file 'image_data/12670.jpg' already exists, won't be pushed. Count: 146
# The file 'image_data/16369.jpg' already exists, won't be pushed. Count: 147
# The file 'image_data/10712.jpg' already exists, won't be pushed. Count: 148
# The file 'image_data/13313.jpg' already exists, won't be pushed. Count: 149
# The file 'image_data/10115.jpg' already exists, won't be pushed. Count: 150
# The file 'image_data/11337.jpg' already exists, won't be pushed. Count: 151
# The file 'image_data/10963.jpg' already exists, won't be pushed. Count: 152
# The file 'image_data/17482.jpg' already exists, won't be pushed. Count: 153
# The file 'image_data/17924.jpg' already exists, won't be pushed. Count: 154
# The file 'image_data/12850.jpg' already exists, won't be pushed. Count: 155
# The file 'image_data/14514.jpg' already exists, won't be pushed. Count: 156
# The file 'image_data/16540.jpg' already exists, won't be pushed. Count: 157
# The file 'image_data/13900.jpg' already exists, won't be pushed. Count: 158
# The file 'image_data/17426.jpg' already exists, won't be pushed. Count: 159
# The file 'image_data/12997.jpg' already exists, won't be pushed. Count: 160
# The file 'image_data/13200.jpg' already exists, won't be pushed. Count: 161
# The file 'image_data/15556.jpg' already exists, won't be pushed. Count: 162
# The file 'image_data/17016.jpg' already exists, won't be pushed. Count: 163
# The file 'image_data/11065.jpg' already exists, won't be pushed. Count: 164
# The file 'image_data/14015.jpg' already exists, won't be pushed. Count: 165
# The file 'image_data/13512.jpg' already exists, won't be pushed. Count: 166
# The file 'image_data/13169.jpg' already exists, won't be pushed. Count: 167
# The file 'image_data/12890.jpg' already exists, won't be pushed. Count: 168
# The file 'image_data/15026.jpg' already exists, won't be pushed. Count: 169
# The file 'image_data/15333.jpg' already exists, won't be pushed. Count: 170
# The file 'image_data/17107.jpg' already exists, won't be pushed. Count: 171
# The file 'image_data/12832.jpg' already exists, won't be pushed. Count: 172
# The file 'image_data/12321.jpg' already exists, won't be pushed. Count: 173
# The file 'image_data/16342.jpg' already exists, won't be pushed. Count: 174
# The file 'image_data/10797.jpg' already exists, won't be pushed. Count: 175
# The file 'image_data/13070.jpg' already exists, won't be pushed. Count: 176
# The file 'image_data/11431.jpg' already exists, won't be pushed. Count: 177
# The file 'image_data/14471.jpg' already exists, won't be pushed. Count: 178
# The file 'image_data/14235.jpg' already exists, won't be pushed. Count: 179
# The file 'image_data/13722.jpg' already exists, won't be pushed. Count: 180
# The file 'image_data/11387.jpg' already exists, won't be pushed. Count: 181
# The file 'image_data/17812.jpg' already exists, won't be pushed. Count: 182
# The file 'image_data/12123.jpg' already exists, won't be pushed. Count: 183
# The file 'image_data/11069.jpg' already exists, won't be pushed. Count: 184
# The file 'image_data/13244.jpg' already exists, won't be pushed. Count: 185
# The file 'image_data/11260.jpg' already exists, won't be pushed. Count: 186
# The file 'image_data/17748.jpg' already exists, won't be pushed. Count: 187
# The file 'image_data/15017.jpg' already exists, won't be pushed. Count: 188
# The file 'image_data/12867.jpg' already exists, won't be pushed. Count: 189
# The file 'image_data/13642.jpg' already exists, won't be pushed. Count: 190
# The file 'image_data/17406.jpg' already exists, won't be pushed. Count: 191
# The file 'image_data/17956.jpg' already exists, won't be pushed. Count: 192
# The file 'image_data/10315.jpg' already exists, won't be pushed. Count: 193
# The file 'image_data/17496.jpg' already exists, won't be pushed. Count: 194
# The file 'image_data/15303.jpg' already exists, won't be pushed. Count: 195
# The file 'image_data/14205.jpg' already exists, won't be pushed. Count: 196
# The file 'image_data/18086.jpg' already exists, won't be pushed. Count: 197
# The file 'image_data/10177.jpg' already exists, won't be pushed. Count: 198
# The file 'image_data/17906.jpg' already exists, won't be pushed. Count: 199
# The file 'image_data/16113.jpg' already exists, won't be pushed. Count: 200
# The file 'image_data/15933.jpg' already exists, won't be pushed. Count: 201
# The file 'image_data/13363.jpg' already exists, won't be pushed. Count: 202
# The file 'image_data/11443.jpg' already exists, won't be pushed. Count: 203
# The file 'image_data/17532.jpg' already exists, won't be pushed. Count: 204
# The file 'image_data/15982.jpg' already exists, won't be pushed. Count: 205
# The file 'image_data/10394.jpg' already exists, won't be pushed. Count: 206
# The file 'image_data/17515.jpg' already exists, won't be pushed. Count: 207
# The file 'image_data/11533.jpg' already exists, won't be pushed. Count: 208
# The file 'image_data/17256.jpg' already exists, won't be pushed. Count: 209
# The file 'image_data/15847.jpg' already exists, won't be pushed. Count: 210
# The file 'image_data/11614.jpg' already exists, won't be pushed. Count: 211
# The file 'image_data/17622.jpg' already exists, won't be pushed. Count: 212
# The file 'image_data/13916.jpg' already exists, won't be pushed. Count: 213
# The file 'image_data/15212.jpg' already exists, won't be pushed. Count: 214
# The file 'image_data/17226.jpg' already exists, won't be pushed. Count: 215
# The file 'image_data/10784.jpg' already exists, won't be pushed. Count: 216
# The file 'image_data/16886.jpg' already exists, won't be pushed. Count: 217
# The file 'image_data/13793.jpg' already exists, won't be pushed. Count: 218
# The file 'image_data/10593.jpg' already exists, won't be pushed. Count: 219
# The file 'image_data/12458.jpg' already exists, won't be pushed. Count: 220
# The file 'image_data/11607.jpg' already exists, won't be pushed. Count: 221
# The file 'image_data/15219.jpg' already exists, won't be pushed. Count: 222
# The file 'image_data/15385.jpg' already exists, won't be pushed. Count: 223
# The file 'image_data/14325.jpg' already exists, won't be pushed. Count: 224
# The file 'image_data/13651.jpg' already exists, won't be pushed. Count: 225
# The file 'image_data/17753.jpg' already exists, won't be pushed. Count: 226
# The file 'image_data/15874.jpg' already exists, won't be pushed. Count: 227
# The file 'image_data/14398.jpg' already exists, won't be pushed. Count: 228
# The file 'image_data/16936.jpg' already exists, won't be pushed. Count: 229
# The file 'image_data/15230.jpg' already exists, won't be pushed. Count: 230
# The file 'image_data/10491.jpg' already exists, won't be pushed. Count: 231
# The file 'image_data/12494.jpg' already exists, won't be pushed. Count: 232
# The file 'image_data/11870.jpg' already exists, won't be pushed. Count: 233
# The file 'image_data/11347.jpg' already exists, won't be pushed. Count: 234
# The file 'image_data/15316.jpg' already exists, won't be pushed. Count: 235
# The file 'image_data/18189.jpg' already exists, won't be pushed. Count: 236
# The file 'image_data/14448.jpg' already exists, won't be pushed. Count: 237
# The file 'image_data/17313.jpg' already exists, won't be pushed. Count: 238
# The file 'image_data/13002.jpg' already exists, won't be pushed. Count: 239
# The file 'image_data/13289.jpg' already exists, won't be pushed. Count: 240
# The file 'image_data/14730.jpg' already exists, won't be pushed. Count: 241
# The file 'image_data/10618.jpg' already exists, won't be pushed. Count: 242
# The file 'image_data/13319.jpg' already exists, won't be pushed. Count: 243
# The file 'image_data/14259.jpg' already exists, won't be pushed. Count: 244
# The file 'image_data/17777.jpg' already exists, won't be pushed. Count: 245
# The file 'image_data/14057.jpg' already exists, won't be pushed. Count: 246
# The file 'image_data/15528.jpg' already exists, won't be pushed. Count: 247
# The file 'image_data/11494.jpg' already exists, won't be pushed. Count: 248
# The file 'image_data/14430.jpg' already exists, won't be pushed. Count: 249
# The file 'image_data/16025.jpg' already exists, won't be pushed. Count: 250
# The file 'image_data/16389.jpg' already exists, won't be pushed. Count: 251
# The file 'image_data/14950.jpg' already exists, won't be pushed. Count: 252
# The file 'image_data/13037.jpg' already exists, won't be pushed. Count: 253
# The file 'image_data/17627.jpg' already exists, won't be pushed. Count: 254
# The file 'image_data/14291.jpg' already exists, won't be pushed. Count: 255
# The file 'image_data/16618.jpg' already exists, won't be pushed. Count: 256
# The file 'image_data/12419.jpg' already exists, won't be pushed. Count: 257
# The file 'image_data/10311.jpg' already exists, won't be pushed. Count: 258
# The file 'image_data/10577.jpg' already exists, won't be pushed. Count: 259
# The file 'image_data/12030.jpg' already exists, won't be pushed. Count: 260
# The file 'image_data/16893.jpg' already exists, won't be pushed. Count: 261
# The file 'image_data/11531.jpg' already exists, won't be pushed. Count: 262
# The file 'image_data/10502.jpg' already exists, won't be pushed. Count: 263
# The file 'image_data/14218.jpg' already exists, won't be pushed. Count: 264
# The file 'image_data/16404.jpg' already exists, won't be pushed. Count: 265
# The file 'image_data/13934.jpg' already exists, won't be pushed. Count: 266
# The file 'image_data/14811.jpg' already exists, won't be pushed. Count: 267
# The file 'image_data/15174.jpg' already exists, won't be pushed. Count: 268
# The file 'image_data/14878.jpg' already exists, won't be pushed. Count: 269
# The file 'image_data/13017.jpg' already exists, won't be pushed. Count: 270
# The file 'image_data/14244.jpg' already exists, won't be pushed. Count: 271
# The file 'image_data/14169.jpg' already exists, won't be pushed. Count: 272
# The file 'image_data/17296.jpg' already exists, won't be pushed. Count: 273
# The file 'image_data/11297.jpg' already exists, won't be pushed. Count: 274
# The file 'image_data/15600.jpg' already exists, won't be pushed. Count: 275
# The file 'image_data/15515.jpg' already exists, won't be pushed. Count: 276
# The file 'image_data/18077.jpg' already exists, won't be pushed. Count: 277
# The file 'image_data/12853.jpg' already exists, won't be pushed. Count: 278
# The file 'image_data/13419.jpg' already exists, won't be pushed. Count: 279
# The file 'image_data/16259.jpg' already exists, won't be pushed. Count: 280
# The file 'image_data/11519.jpg' already exists, won't be pushed. Count: 281
# The file 'image_data/10804.jpg' already exists, won't be pushed. Count: 282
# The file 'image_data/14757.jpg' already exists, won't be pushed. Count: 283
# The file 'image_data/12133.jpg' already exists, won't be pushed. Count: 284
# The file 'image_data/14987.jpg' already exists, won't be pushed. Count: 285
# The file 'image_data/15942.jpg' already exists, won't be pushed. Count: 286
# The file 'image_data/10669.jpg' already exists, won't be pushed. Count: 287
# The file 'image_data/17554.jpg' already exists, won't be pushed. Count: 288
# The file 'image_data/14782.jpg' already exists, won't be pushed. Count: 289
# The file 'image_data/17886.jpg' already exists, won't be pushed. Count: 290
# The file 'image_data/15913.jpg' already exists, won't be pushed. Count: 291
# The file 'image_data/12463.jpg' already exists, won't be pushed. Count: 292
# The file 'image_data/18042.jpg' already exists, won't be pushed. Count: 293
# The file 'image_data/14054.jpg' already exists, won't be pushed. Count: 294
# The file 'image_data/11745.jpg' already exists, won't be pushed. Count: 295
# The file 'image_data/15756.jpg' already exists, won't be pushed. Count: 296
# The file 'image_data/17613.jpg' already exists, won't be pushed. Count: 297
# The file 'image_data/11063.jpg' already exists, won't be pushed. Count: 298
# The file 'image_data/11226.jpg' already exists, won't be pushed. Count: 299
# The file 'image_data/15069.jpg' already exists, won't be pushed. Count: 300
# The file 'image_data/12815.jpg' already exists, won't be pushed. Count: 301
# The file 'image_data/10439.jpg' already exists, won't be pushed. Count: 302
# The file 'image_data/15581.jpg' already exists, won't be pushed. Count: 303
# The file 'image_data/14602.jpg' already exists, won't be pushed. Count: 304
# The file 'image_data/12749.jpg' already exists, won't be pushed. Count: 305
# The file 'image_data/10859.jpg' already exists, won't be pushed. Count: 306
# The file 'image_data/17057.jpg' already exists, won't be pushed. Count: 307
# The file 'image_data/13779.jpg' already exists, won't be pushed. Count: 308
# The file 'image_data/10089.jpg' already exists, won't be pushed. Count: 309
# The file 'image_data/10932.jpg' already exists, won't be pushed. Count: 310
# The file 'image_data/12431.jpg' already exists, won't be pushed. Count: 311
# The file 'image_data/12084.jpg' already exists, won't be pushed. Count: 312
# The file 'image_data/14709.jpg' already exists, won't be pushed. Count: 313
# The file 'image_data/12899.jpg' already exists, won't be pushed. Count: 314
# The file 'image_data/11279.jpg' already exists, won't be pushed. Count: 315
# The file 'image_data/16418.jpg' already exists, won't be pushed. Count: 316
# The file 'image_data/10617.jpg' already exists, won't be pushed. Count: 317
# The file 'image_data/16977.jpg' already exists, won't be pushed. Count: 318
# The file 'image_data/11615.jpg' already exists, won't be pushed. Count: 319
# The file 'image_data/13229.jpg' already exists, won't be pushed. Count: 320
# The file 'image_data/15538.jpg' already exists, won't be pushed. Count: 321
# The file 'image_data/12249.jpg' already exists, won't be pushed. Count: 322
# The file 'image_data/16596.jpg' already exists, won't be pushed. Count: 323
# The file 'image_data/12108.jpg' already exists, won't be pushed. Count: 324
# The file 'image_data/11241.jpg' already exists, won't be pushed. Count: 325
# The file 'image_data/14229.jpg' already exists, won't be pushed. Count: 326
# The file 'image_data/11764.jpg' already exists, won't be pushed. Count: 327
# The file 'image_data/15900.jpg' already exists, won't be pushed. Count: 328
# The file 'image_data/13311.jpg' already exists, won't be pushed. Count: 329
# The file 'image_data/18204.jpg' already exists, won't be pushed. Count: 330
# The file 'image_data/12132.jpg' already exists, won't be pushed. Count: 331
# The file 'image_data/18096.jpg' already exists, won't be pushed. Count: 332
# The file 'image_data/15294.jpg' already exists, won't be pushed. Count: 333
# The file 'image_data/11218.jpg' already exists, won't be pushed. Count: 334
# The file 'image_data/14314.jpg' already exists, won't be pushed. Count: 335
# The file 'image_data/11280.jpg' already exists, won't be pushed. Count: 336
# The file 'image_data/16930.jpg' already exists, won't be pushed. Count: 337
# The file 'image_data/13802.jpg' already exists, won't be pushed. Count: 338
# The file 'image_data/16730.jpg' already exists, won't be pushed. Count: 339
# The file 'image_data/17092.jpg' already exists, won't be pushed. Count: 340
# The file 'image_data/14134.jpg' already exists, won't be pushed. Count: 341
# The file 'image_data/17324.jpg' already exists, won't be pushed. Count: 342
# The file 'image_data/17921.jpg' already exists, won't be pushed. Count: 343
# The file 'image_data/12606.jpg' already exists, won't be pushed. Count: 344
# The file 'image_data/16674.jpg' already exists, won't be pushed. Count: 345
# The file 'image_data/11471.jpg' already exists, won't be pushed. Count: 346
# The file 'image_data/16648.jpg' already exists, won't be pushed. Count: 347
# The file 'image_data/18060.jpg' already exists, won't be pushed. Count: 348
# The file 'image_data/11809.jpg' already exists, won't be pushed. Count: 349
# The file 'image_data/13646.jpg' already exists, won't be pushed. Count: 350
# The file 'image_data/13563.jpg' already exists, won't be pushed. Count: 351
# The file 'image_data/11356.jpg' already exists, won't be pushed. Count: 352
# The file 'image_data/16036.jpg' already exists, won't be pushed. Count: 353
# The file 'image_data/14216.jpg' already exists, won't be pushed. Count: 354
# The file 'image_data/14304.jpg' already exists, won't be pushed. Count: 355
# The file 'image_data/13212.jpg' already exists, won't be pushed. Count: 356
# The file 'image_data/17597.jpg' already exists, won't be pushed. Count: 357
# The file 'image_data/10553.jpg' already exists, won't be pushed. Count: 358
# The file 'image_data/14436.jpg' already exists, won't be pushed. Count: 359
# The file 'image_data/16686.jpg' already exists, won't be pushed. Count: 360
# The file 'image_data/17499.jpg' already exists, won't be pushed. Count: 361
# The file 'image_data/14871.jpg' already exists, won't be pushed. Count: 362
# The file 'image_data/14416.jpg' already exists, won't be pushed. Count: 363
# The file 'image_data/13279.jpg' already exists, won't be pushed. Count: 364
# The file 'image_data/16827.jpg' already exists, won't be pushed. Count: 365
# The file 'image_data/16093.jpg' already exists, won't be pushed. Count: 366
# The file 'image_data/14856.jpg' already exists, won't be pushed. Count: 367
# The file 'image_data/14533.jpg' already exists, won't be pushed. Count: 368
# The file 'image_data/13775.jpg' already exists, won't be pushed. Count: 369
# The file 'image_data/10081.jpg' already exists, won't be pushed. Count: 370
# The file 'image_data/11623.jpg' already exists, won't be pushed. Count: 371
# The file 'image_data/12340.jpg' already exists, won't be pushed. Count: 372
# The file 'image_data/14293.jpg' already exists, won't be pushed. Count: 373
# The file 'image_data/13828.jpg' already exists, won't be pushed. Count: 374
# The file 'image_data/18201.jpg' already exists, won't be pushed. Count: 375
# The file 'image_data/12427.jpg' already exists, won't be pushed. Count: 376
# The file 'image_data/10611.jpg' already exists, won't be pushed. Count: 377
# The file 'image_data/15954.jpg' already exists, won't be pushed. Count: 378
# The file 'image_data/11887.jpg' already exists, won't be pushed. Count: 379
# The file 'image_data/13924.jpg' already exists, won't be pushed. Count: 380
# The file 'image_data/13552.jpg' already exists, won't be pushed. Count: 381
# The file 'image_data/10776.jpg' already exists, won't be pushed. Count: 382
# The file 'image_data/10231.jpg' already exists, won't be pushed. Count: 383
# The file 'image_data/10741.jpg' already exists, won't be pushed. Count: 384
# The file 'image_data/15868.jpg' already exists, won't be pushed. Count: 385
# The file 'image_data/12506.jpg' already exists, won't be pushed. Count: 386
# The file 'image_data/13846.jpg' already exists, won't be pushed. Count: 387
# The file 'image_data/11327.jpg' already exists, won't be pushed. Count: 388
# The file 'image_data/12808.jpg' already exists, won't be pushed. Count: 389
# The file 'image_data/14213.jpg' already exists, won't be pushed. Count: 390
# The file 'image_data/17053.jpg' already exists, won't be pushed. Count: 391
# The file 'image_data/16402.jpg' already exists, won't be pushed. Count: 392
# The file 'image_data/12963.jpg' already exists, won't be pushed. Count: 393
# The file 'image_data/11784.jpg' already exists, won't be pushed. Count: 394
# The file 'image_data/11925.jpg' already exists, won't be pushed. Count: 395
# The file 'image_data/16501.jpg' already exists, won't be pushed. Count: 396
# The file 'image_data/14466.jpg' already exists, won't be pushed. Count: 397
# The file 'image_data/10357.jpg' already exists, won't be pushed. Count: 398
# The file 'image_data/11528.jpg' already exists, won't be pushed. Count: 399
# The file 'image_data/11480.jpg' already exists, won't be pushed. Count: 400
# The file 'image_data/12865.jpg' already exists, won't be pushed. Count: 401
# The file 'image_data/14933.jpg' already exists, won't be pushed. Count: 402
# The file 'image_data/15585.jpg' already exists, won't be pushed. Count: 403
# The file 'image_data/10519.jpg' already exists, won't be pushed. Count: 404
# The file 'image_data/14519.jpg' already exists, won't be pushed. Count: 405
# The file 'image_data/16736.jpg' already exists, won't be pushed. Count: 406
# The file 'image_data/10713.jpg' already exists, won't be pushed. Count: 407
# The file 'image_data/11911.jpg' already exists, won't be pushed. Count: 408
# The file 'image_data/15315.jpg' already exists, won't be pushed. Count: 409
# The file 'image_data/15968.jpg' already exists, won't be pushed. Count: 410
# The file 'image_data/10383.jpg' already exists, won't be pushed. Count: 411
# The file 'image_data/10539.jpg' already exists, won't be pushed. Count: 412
# The file 'image_data/15073.jpg' already exists, won't be pushed. Count: 413
# The file 'image_data/12212.jpg' already exists, won't be pushed. Count: 414
# The file 'image_data/14610.jpg' already exists, won't be pushed. Count: 415
# The file 'image_data/10673.jpg' already exists, won't be pushed. Count: 416
# The file 'image_data/12568.jpg' already exists, won't be pushed. Count: 417
# The file 'image_data/13300.jpg' already exists, won't be pushed. Count: 418
# The file 'image_data/17766.jpg' already exists, won't be pushed. Count: 419
# The file 'image_data/17061.jpg' already exists, won't be pushed. Count: 420
# The file 'image_data/14400.jpg' already exists, won't be pushed. Count: 421
# The file 'image_data/12615.jpg' already exists, won't be pushed. Count: 422
# The file 'image_data/15801.jpg' already exists, won't be pushed. Count: 423
# The file 'image_data/10803.jpg' already exists, won't be pushed. Count: 424
# The file 'image_data/10090.jpg' already exists, won't be pushed. Count: 425
# The file 'image_data/17069.jpg' already exists, won't be pushed. Count: 426
# The file 'image_data/16708.jpg' already exists, won't be pushed. Count: 427
# The file 'image_data/10333.jpg' already exists, won't be pushed. Count: 428
# The file 'image_data/12645.jpg' already exists, won't be pushed. Count: 429
# The file 'image_data/13338.jpg' already exists, won't be pushed. Count: 430
# The file 'image_data/15723.jpg' already exists, won't be pushed. Count: 431
# The file 'image_data/11863.jpg' already exists, won't be pushed. Count: 432
# The file 'image_data/16970.jpg' already exists, won't be pushed. Count: 433
# The file 'image_data/17464.jpg' already exists, won't be pushed. Count: 434
# The file 'image_data/16040.jpg' already exists, won't be pushed. Count: 435
# The file 'image_data/12348.jpg' already exists, won't be pushed. Count: 436
# The file 'image_data/17090.jpg' already exists, won't be pushed. Count: 437
# The file 'image_data/12610.jpg' already exists, won't be pushed. Count: 438
# The file 'image_data/13498.jpg' already exists, won't be pushed. Count: 439
# The file 'image_data/13582.jpg' already exists, won't be pushed. Count: 440
# The file 'image_data/13172.jpg' already exists, won't be pushed. Count: 441
# The file 'image_data/15150.jpg' already exists, won't be pushed. Count: 442
# The file 'image_data/10984.jpg' already exists, won't be pushed. Count: 443
# The file 'image_data/11619.jpg' already exists, won't be pushed. Count: 444
# The file 'image_data/12523.jpg' already exists, won't be pushed. Count: 445
# The file 'image_data/17475.jpg' already exists, won't be pushed. Count: 446
# The file 'image_data/12011.jpg' already exists, won't be pushed. Count: 447
# The file 'image_data/12664.jpg' already exists, won't be pushed. Count: 448
# The file 'image_data/10062.jpg' already exists, won't be pushed. Count: 449
# The file 'image_data/14433.jpg' already exists, won't be pushed. Count: 450
# The file 'image_data/11196.jpg' already exists, won't be pushed. Count: 451
# The file 'image_data/11176.jpg' already exists, won't be pushed. Count: 452
# The file 'image_data/10747.jpg' already exists, won't be pushed. Count: 453
# The file 'image_data/14351.jpg' already exists, won't be pushed. Count: 454
# The file 'image_data/16443.jpg' already exists, won't be pushed. Count: 455
# The file 'image_data/16989.jpg' already exists, won't be pushed. Count: 456
# The file 'image_data/11897.jpg' already exists, won't be pushed. Count: 457
# The file 'image_data/17091.jpg' already exists, won't be pushed. Count: 458
# The file 'image_data/13850.jpg' already exists, won't be pushed. Count: 459
# The file 'image_data/18054.jpg' already exists, won't be pushed. Count: 460
# The file 'image_data/16187.jpg' already exists, won't be pushed. Count: 461
# The file 'image_data/11047.jpg' already exists, won't be pushed. Count: 462
# The file 'image_data/14779.jpg' already exists, won't be pushed. Count: 463
# The file 'image_data/12720.jpg' already exists, won't be pushed. Count: 464
# The file 'image_data/13564.jpg' already exists, won't be pushed. Count: 465
# The file 'image_data/10192.jpg' already exists, won't be pushed. Count: 466
# The file 'image_data/14424.jpg' already exists, won't be pushed. Count: 467
# The file 'image_data/15971.jpg' already exists, won't be pushed. Count: 468
# The file 'image_data/17752.jpg' already exists, won't be pushed. Count: 469
# The file 'image_data/15835.jpg' already exists, won't be pushed. Count: 470
# The file 'image_data/13281.jpg' already exists, won't be pushed. Count: 471
# The file 'image_data/17794.jpg' already exists, won't be pushed. Count: 472
# The file 'image_data/14270.jpg' already exists, won't be pushed. Count: 473
# The file 'image_data/15155.jpg' already exists, won't be pushed. Count: 474
# The file 'image_data/11395.jpg' already exists, won't be pushed. Count: 475
# The file 'image_data/14171.jpg' already exists, won't be pushed. Count: 476
# The file 'image_data/17403.jpg' already exists, won't be pushed. Count: 477
# The file 'image_data/11832.jpg' already exists, won't be pushed. Count: 478
# The file 'image_data/15389.jpg' already exists, won't be pushed. Count: 479
# The file 'image_data/14550.jpg' already exists, won't be pushed. Count: 480
# The file 'image_data/11602.jpg' already exists, won't be pushed. Count: 481
# The file 'image_data/11664.jpg' already exists, won't be pushed. Count: 482
# The file 'image_data/11751.jpg' already exists, won't be pushed. Count: 483
# The file 'image_data/15940.jpg' already exists, won't be pushed. Count: 484
# The file 'image_data/17440.jpg' already exists, won't be pushed. Count: 485
# The file 'image_data/17541.jpg' already exists, won't be pushed. Count: 486
# The file 'image_data/14458.jpg' already exists, won't be pushed. Count: 487
# The file 'image_data/17088.jpg' already exists, won't be pushed. Count: 488
# The file 'image_data/11578.jpg' already exists, won't be pushed. Count: 489
# The file 'image_data/13701.jpg' already exists, won't be pushed. Count: 490
# The file 'image_data/12715.jpg' already exists, won't be pushed. Count: 491
# The file 'image_data/10398.jpg' already exists, won't be pushed. Count: 492
# The file 'image_data/15721.jpg' already exists, won't be pushed. Count: 493
# The file 'image_data/14603.jpg' already exists, won't be pushed. Count: 494
# The file 'image_data/11015.jpg' already exists, won't be pushed. Count: 495
# The file 'image_data/16853.jpg' already exists, won't be pushed. Count: 496
# The file 'image_data/17894.jpg' already exists, won't be pushed. Count: 497
# The file 'image_data/17294.jpg' already exists, won't be pushed. Count: 498
# The file 'image_data/16530.jpg' already exists, won't be pushed. Count: 499
# The file 'image_data/16701.jpg' already exists, won't be pushed. Count: 500
# The file 'image_data/10876.jpg' already exists, won't be pushed. Count: 501
# The file 'image_data/12237.jpg' already exists, won't be pushed. Count: 502
# The file 'image_data/11352.jpg' already exists, won't be pushed. Count: 503
# The file 'image_data/11994.jpg' already exists, won't be pushed. Count: 504
# The file 'image_data/11978.jpg' already exists, won't be pushed. Count: 505
# The file 'image_data/17524.jpg' already exists, won't be pushed. Count: 506
# The file 'image_data/16280.jpg' already exists, won't be pushed. Count: 507
# The file 'image_data/16560.jpg' already exists, won't be pushed. Count: 508
# The file 'image_data/15323.jpg' already exists, won't be pushed. Count: 509
# The file 'image_data/16548.jpg' already exists, won't be pushed. Count: 510
# The file 'image_data/17081.jpg' already exists, won't be pushed. Count: 511
# The file 'image_data/16981.jpg' already exists, won't be pushed. Count: 512
# The file 'image_data/12895.jpg' already exists, won't be pushed. Count: 513
# The file 'image_data/16871.jpg' already exists, won't be pushed. Count: 514
# The file 'image_data/15573.jpg' already exists, won't be pushed. Count: 515
# The file 'image_data/12314.jpg' already exists, won't be pushed. Count: 516
# The file 'image_data/14485.jpg' already exists, won't be pushed. Count: 517
# The file 'image_data/15223.jpg' already exists, won't be pushed. Count: 518
# The file 'image_data/15265.jpg' already exists, won't be pushed. Count: 519
# The file 'image_data/15557.jpg' already exists, won't be pushed. Count: 520
# The file 'image_data/13540.jpg' already exists, won't be pushed. Count: 521
# The file 'image_data/10706.jpg' already exists, won't be pushed. Count: 522
# The file 'image_data/10222.jpg' already exists, won't be pushed. Count: 523
# The file 'image_data/11331.jpg' already exists, won't be pushed. Count: 524
# The file 'image_data/18154.jpg' already exists, won't be pushed. Count: 525
# The file 'image_data/11927.jpg' already exists, won't be pushed. Count: 526
# The file 'image_data/14806.jpg' already exists, won't be pushed. Count: 527
# The file 'image_data/11418.jpg' already exists, won't be pushed. Count: 528
# The file 'image_data/13682.jpg' already exists, won't be pushed. Count: 529
# The file 'image_data/14639.jpg' already exists, won't be pushed. Count: 530
# The file 'image_data/14452.jpg' already exists, won't be pushed. Count: 531
# The file 'image_data/13039.jpg' already exists, won't be pushed. Count: 532
# The file 'image_data/10299.jpg' already exists, won't be pushed. Count: 533
# The file 'image_data/17644.jpg' already exists, won't be pushed. Count: 534
# The file 'image_data/13235.jpg' already exists, won't be pushed. Count: 535
# The file 'image_data/16780.jpg' already exists, won't be pushed. Count: 536
# The file 'image_data/13589.jpg' already exists, won't be pushed. Count: 537
# The file 'image_data/10382.jpg' already exists, won't be pushed. Count: 538
# The file 'image_data/18089.jpg' already exists, won't be pushed. Count: 539
# The file 'image_data/10866.jpg' already exists, won't be pushed. Count: 540
# The file 'image_data/10936.jpg' already exists, won't be pushed. Count: 541
# The file 'image_data/17814.jpg' already exists, won't be pushed. Count: 542
# The file 'image_data/18109.jpg' already exists, won't be pushed. Count: 543
# The file 'image_data/17250.jpg' already exists, won't be pushed. Count: 544
# The file 'image_data/10630.jpg' already exists, won't be pushed. Count: 545
# The file 'image_data/17926.jpg' already exists, won't be pushed. Count: 546
# The file 'image_data/16359.jpg' already exists, won't be pushed. Count: 547
# The file 'image_data/16151.jpg' already exists, won't be pushed. Count: 548
# The file 'image_data/14924.jpg' already exists, won't be pushed. Count: 549
# The file 'image_data/16461.jpg' already exists, won't be pushed. Count: 550
# The file 'image_data/15430.jpg' already exists, won't be pushed. Count: 551
# The file 'image_data/16364.jpg' already exists, won't be pushed. Count: 552
# The file 'image_data/12602.jpg' already exists, won't be pushed. Count: 553
# The file 'image_data/17230.jpg' already exists, won't be pushed. Count: 554
# The file 'image_data/17143.jpg' already exists, won't be pushed. Count: 555
# The file 'image_data/14512.jpg' already exists, won't be pushed. Count: 556
# The file 'image_data/14486.jpg' already exists, won't be pushed. Count: 557
# The file 'image_data/13394.jpg' already exists, won't be pushed. Count: 558
# The file 'image_data/16138.jpg' already exists, won't be pushed. Count: 559
# The file 'image_data/12914.jpg' already exists, won't be pushed. Count: 560
# The file 'image_data/12086.jpg' already exists, won't be pushed. Count: 561
# The file 'image_data/14756.jpg' already exists, won't be pushed. Count: 562
# The file 'image_data/13908.jpg' already exists, won't be pushed. Count: 563
# The file 'image_data/12242.jpg' already exists, won't be pushed. Count: 564
# The file 'image_data/14660.jpg' already exists, won't be pushed. Count: 565
# The file 'image_data/17047.jpg' already exists, won't be pushed. Count: 566
# The file 'image_data/13464.jpg' already exists, won't be pushed. Count: 567
# The file 'image_data/16711.jpg' already exists, won't be pushed. Count: 568
# The file 'image_data/13305.jpg' already exists, won't be pushed. Count: 569
# The file 'image_data/15977.jpg' already exists, won't be pushed. Count: 570
# The file 'image_data/18113.jpg' already exists, won't be pushed. Count: 571
# The file 'image_data/17456.jpg' already exists, won't be pushed. Count: 572
# The file 'image_data/13960.jpg' already exists, won't be pushed. Count: 573
# The file 'image_data/17289.jpg' already exists, won't be pushed. Count: 574
# The file 'image_data/12721.jpg' already exists, won't be pushed. Count: 575
# The file 'image_data/17036.jpg' already exists, won't be pushed. Count: 576
# The file 'image_data/10093.jpg' already exists, won't be pushed. Count: 577
# The file 'image_data/10835.jpg' already exists, won't be pushed. Count: 578
# The file 'image_data/10269.jpg' already exists, won't be pushed. Count: 579
# The file 'image_data/10826.jpg' already exists, won't be pushed. Count: 580
# The file 'image_data/12481.jpg' already exists, won't be pushed. Count: 581
# The file 'image_data/10640.jpg' already exists, won't be pushed. Count: 582
# The file 'image_data/10301.jpg' already exists, won't be pushed. Count: 583
# The file 'image_data/11952.jpg' already exists, won't be pushed. Count: 584
# The file 'image_data/14287.jpg' already exists, won't be pushed. Count: 585
# The file 'image_data/17196.jpg' already exists, won't be pushed. Count: 586
# The file 'image_data/13996.jpg' already exists, won't be pushed. Count: 587
# The file 'image_data/12612.jpg' already exists, won't be pushed. Count: 588
# The file 'image_data/13495.jpg' already exists, won't be pushed. Count: 589
# The file 'image_data/11718.jpg' already exists, won't be pushed. Count: 590
# The file 'image_data/16987.jpg' already exists, won't be pushed. Count: 591
# The file 'image_data/15558.jpg' already exists, won't be pushed. Count: 592
# The file 'image_data/10989.jpg' already exists, won't be pushed. Count: 593
# The file 'image_data/12745.jpg' already exists, won't be pushed. Count: 594
# The file 'image_data/10051.jpg' already exists, won't be pushed. Count: 595
# The file 'image_data/11469.jpg' already exists, won't be pushed. Count: 596
# The file 'image_data/16645.jpg' already exists, won't be pushed. Count: 597
# The file 'image_data/18168.jpg' already exists, won't be pushed. Count: 598
# The file 'image_data/10900.jpg' already exists, won't be pushed. Count: 599
# The file 'image_data/15739.jpg' already exists, won't be pushed. Count: 600
# The file 'image_data/17703.jpg' already exists, won't be pushed. Count: 601
# The file 'image_data/11704.jpg' already exists, won't be pushed. Count: 602
# The file 'image_data/17023.jpg' already exists, won't be pushed. Count: 603
# The file 'image_data/12570.jpg' already exists, won't be pushed. Count: 604
# The file 'image_data/12417.jpg' already exists, won't be pushed. Count: 605
# The file 'image_data/12454.jpg' already exists, won't be pushed. Count: 606
# The file 'image_data/11982.jpg' already exists, won't be pushed. Count: 607
# The file 'image_data/11173.jpg' already exists, won't be pushed. Count: 608
# The file 'image_data/13328.jpg' already exists, won't be pushed. Count: 609
# The file 'image_data/14507.jpg' already exists, won't be pushed. Count: 610
# The file 'image_data/14495.jpg' already exists, won't be pushed. Count: 611
# The file 'image_data/17177.jpg' already exists, won't be pushed. Count: 612
# The file 'image_data/14191.jpg' already exists, won't be pushed. Count: 613
# The file 'image_data/18071.jpg' already exists, won't be pushed. Count: 614
# The file 'image_data/13475.jpg' already exists, won't be pushed. Count: 615
# The file 'image_data/17387.jpg' already exists, won't be pushed. Count: 616
# The file 'image_data/14803.jpg' already exists, won't be pushed. Count: 617
# The file 'image_data/14087.jpg' already exists, won't be pushed. Count: 618
# The file 'image_data/17520.jpg' already exists, won't be pushed. Count: 619
# The file 'image_data/12304.jpg' already exists, won't be pushed. Count: 620
# The file 'image_data/16288.jpg' already exists, won't be pushed. Count: 621
# The file 'image_data/14225.jpg' already exists, won't be pushed. Count: 622
# The file 'image_data/16039.jpg' already exists, won't be pushed. Count: 623
# The file 'image_data/11472.jpg' already exists, won't be pushed. Count: 624
# The file 'image_data/10147.jpg' already exists, won't be pushed. Count: 625
# The file 'image_data/14517.jpg' already exists, won't be pushed. Count: 626
# The file 'image_data/16856.jpg' already exists, won't be pushed. Count: 627
# The file 'image_data/12755.jpg' already exists, won't be pushed. Count: 628
# The file 'image_data/17929.jpg' already exists, won't be pushed. Count: 629
# The file 'image_data/11179.jpg' already exists, won't be pushed. Count: 630
# The file 'image_data/14431.jpg' already exists, won't be pushed. Count: 631
# The file 'image_data/16924.jpg' already exists, won't be pushed. Count: 632
# ...
# The file 'image_data/13886.jpg' already exists, won't be pushed. Count: 5527
# The file 'image_data/11758.jpg' already exists, won't be pushed. Count: 5528
# The file 'image_data/12873.jpg' already exists, won't be pushed. Count: 5529
# The file 'image_data/17902.jpg' already exists, won't be pushed. Count: 5530
# The file 'image_data/17568.jpg' already exists, won't be pushed. Count: 5531
# The file 'image_data/11254.jpg' already exists, won't be pushed. Count: 5532
# The file 'image_data/17327.jpg' already exists, won't be pushed. Count: 5533
# The file 'image_data/17087.jpg' already exists, won't be pushed. Count: 5534
# The file 'image_data/14237.jpg' already exists, won't be pushed. Count: 5535
# The file 'image_data/13887.jpg' already exists, won't be pushed. Count: 5536
# The file 'image_data/17686.jpg' already exists, won't be pushed. Count: 5537
# The file 'image_data/10034.jpg' already exists, won't be pushed. Count: 5538
# The file 'image_data/18145.jpg' already exists, won't be pushed. Count: 5539
# The file 'image_data/10294.jpg' already exists, won't be pushed. Count: 5540
# The file 'image_data/17322.jpg' already exists, won't be pushed. Count: 5541
# The file 'image_data/13997.jpg' already exists, won't be pushed. Count: 5542
# The file 'image_data/14172.jpg' already exists, won't be pushed. Count: 5543
# The file 'image_data/11326.jpg' already exists, won't be pushed. Count: 5544
# The file 'image_data/14796.jpg' already exists, won't be pushed. Count: 5545
# The file 'image_data/14083.jpg' already exists, won't be pushed. Count: 5546
# The file 'image_data/11713.jpg' already exists, won't be pushed. Count: 5547
# The file 'image_data/16883.jpg' already exists, won't be pushed. Count: 5548
# The file 'image_data/12993.jpg' already exists, won't be pushed. Count: 5549
# The file 'image_data/10465.jpg' already exists, won't be pushed. Count: 5550
# The file 'image_data/11983.jpg' already exists, won't be pushed. Count: 5551
# The file 'image_data/15708.jpg' already exists, won't be pushed. Count: 5552
# The file 'image_data/12021.jpg' already exists, won't be pushed. Count: 5553
# The file 'image_data/14674.jpg' already exists, won't be pushed. Count: 5554
# The file 'image_data/12421.jpg' already exists, won't be pushed. Count: 5555
# The file 'image_data/13605.jpg' already exists, won't be pushed. Count: 5556
# The file 'image_data/15819.jpg' already exists, won't be pushed. Count: 5557
# The file 'image_data/12843.jpg' already exists, won't be pushed. Count: 5558
# The file 'image_data/11783.jpg' already exists, won't be pushed. Count: 5559
# The file 'image_data/15224.jpg' already exists, won't be pushed. Count: 5560
# The file 'image_data/12307.jpg' already exists, won't be pushed. Count: 5561
# The file 'image_data/12882.jpg' already exists, won't be pushed. Count: 5562
# The file 'image_data/10524.jpg' already exists, won't be pushed. Count: 5563
# The file 'image_data/11073.jpg' already exists, won't be pushed. Count: 5564
# The file 'image_data/17806.jpg' already exists, won't be pushed. Count: 5565
# The file 'image_data/14958.jpg' already exists, won't be pushed. Count: 5566
# The file 'image_data/15036.jpg' already exists, won't be pushed. Count: 5567
# The file 'image_data/11243.jpg' already exists, won't be pushed. Count: 5568
# The file 'image_data/17042.jpg' already exists, won't be pushed. Count: 5569
# The file 'image_data/15118.jpg' already exists, won't be pushed. Count: 5570
# The file 'image_data/15027.jpg' already exists, won't be pushed. Count: 5571
# The file 'image_data/17817.jpg' already exists, won't be pushed. Count: 5572
# The file 'image_data/10780.jpg' already exists, won't be pushed. Count: 5573
# The file 'image_data/13843.jpg' already exists, won't be pushed. Count: 5574
# The file 'image_data/11530.jpg' already exists, won't be pushed. Count: 5575
# The file 'image_data/18036.jpg' already exists, won't be pushed. Count: 5576
# The file 'image_data/17263.jpg' already exists, won't be pushed. Count: 5577
# The file 'image_data/15439.jpg' already exists, won't be pushed. Count: 5578
# The file 'image_data/17409.jpg' already exists, won't be pushed. Count: 5579
# The file 'image_data/13519.jpg' already exists, won't be pushed. Count: 5580
# The file 'image_data/17540.jpg' already exists, won't be pushed. Count: 5581
# The file 'image_data/16144.jpg' already exists, won't be pushed. Count: 5582
# The file 'image_data/15497.jpg' already exists, won't be pushed. Count: 5583
# The file 'image_data/15379.jpg' already exists, won't be pushed. Count: 5584
# The file 'image_data/11194.jpg' already exists, won't be pushed. Count: 5585
# The file 'image_data/10487.jpg' already exists, won't be pushed. Count: 5586
# The file 'image_data/17634.jpg' already exists, won't be pushed. Count: 5587
# The file 'image_data/12794.jpg' already exists, won't be pushed. Count: 5588
# The file 'image_data/16467.jpg' already exists, won't be pushed. Count: 5589
# The file 'image_data/13878.jpg' already exists, won't be pushed. Count: 5590
# The file 'image_data/10686.jpg' already exists, won't be pushed. Count: 5591
# The file 'image_data/13882.jpg' already exists, won't be pushed. Count: 5592
# The file 'image_data/10076.jpg' already exists, won't be pushed. Count: 5593
# The file 'image_data/11357.jpg' already exists, won't be pushed. Count: 5594
# The file 'image_data/11078.jpg' already exists, won't be pushed. Count: 5595
# The file 'image_data/17046.jpg' already exists, won't be pushed. Count: 5596
# The file 'image_data/14438.jpg' already exists, won't be pushed. Count: 5597
# The file 'image_data/13154.jpg' already exists, won't be pushed. Count: 5598
# The file 'image_data/15650.jpg' already exists, won't be pushed. Count: 5599
# The file 'image_data/16870.jpg' already exists, won't be pushed. Count: 5600
# The file 'image_data/10286.jpg' already exists, won't be pushed. Count: 5601
# The file 'image_data/14530.jpg' already exists, won't be pushed. Count: 5602
# The file 'image_data/13570.jpg' already exists, won't be pushed. Count: 5603
# The file 'image_data/13205.jpg' already exists, won't be pushed. Count: 5604
# The file 'image_data/16567.jpg' already exists, won't be pushed. Count: 5605
# The file 'image_data/11962.jpg' already exists, won't be pushed. Count: 5606
# The file 'image_data/16318.jpg' already exists, won't be pushed. Count: 5607
# The file 'image_data/13743.jpg' already exists, won't be pushed. Count: 5608
# The file 'image_data/12064.jpg' already exists, won't be pushed. Count: 5609
# The file 'image_data/10976.jpg' already exists, won't be pushed. Count: 5610
# The file 'image_data/17908.jpg' already exists, won't be pushed. Count: 5611
# The file 'image_data/15242.jpg' already exists, won't be pushed. Count: 5612
# The file 'image_data/10045.jpg' already exists, won't be pushed. Count: 5613
# The file 'image_data/10600.jpg' already exists, won't be pushed. Count: 5614
# The file 'image_data/13799.jpg' already exists, won't be pushed. Count: 5615
# The file 'image_data/16900.jpg' already exists, won't be pushed. Count: 5616
# The file 'image_data/15588.jpg' already exists, won't be pushed. Count: 5617
# The file 'image_data/14763.jpg' already exists, won't be pushed. Count: 5618
# The file 'image_data/11155.jpg' already exists, won't be pushed. Count: 5619
# The file 'image_data/12101.jpg' already exists, won't be pushed. Count: 5620
# The file 'image_data/16683.jpg' already exists, won't be pushed. Count: 5621
# The file 'image_data/16365.jpg' already exists, won't be pushed. Count: 5622
# The file 'image_data/11008.jpg' already exists, won't be pushed. Count: 5623
# The file 'image_data/16731.jpg' already exists, won't be pushed. Count: 5624
# The file 'image_data/17603.jpg' already exists, won't be pushed. Count: 5625
# The file 'image_data/12149.jpg' already exists, won't be pushed. Count: 5626
# The file 'image_data/13000.jpg' already exists, won't be pushed. Count: 5627
# The file 'image_data/17094.jpg' already exists, won't be pushed. Count: 5628
# The file 'image_data/12050.jpg' already exists, won't be pushed. Count: 5629
# The file 'image_data/12513.jpg' already exists, won't be pushed. Count: 5630
# The file 'image_data/12760.jpg' already exists, won't be pushed. Count: 5631
# The file 'image_data/14669.jpg' already exists, won't be pushed. Count: 5632
# The file 'image_data/11163.jpg' already exists, won't be pushed. Count: 5633
# The file 'image_data/11526.jpg' already exists, won't be pushed. Count: 5634
# The file 'image_data/12276.jpg' already exists, won't be pushed. Count: 5635
# The file 'image_data/13913.jpg' already exists, won't be pushed. Count: 5636
# The file 'image_data/13396.jpg' already exists, won't be pushed. Count: 5637
# The file 'image_data/14160.jpg' already exists, won't be pushed. Count: 5638
# The file 'image_data/12519.jpg' already exists, won't be pushed. Count: 5639
# The file 'image_data/10119.jpg' already exists, won't be pushed. Count: 5640
# The file 'image_data/17940.jpg' already exists, won't be pushed. Count: 5641
# The file 'image_data/13894.jpg' already exists, won't be pushed. Count: 5642
# The file 'image_data/16553.jpg' already exists, won't be pushed. Count: 5643
# The file 'image_data/11499.jpg' already exists, won't be pushed. Count: 5644
# The file 'image_data/16292.jpg' already exists, won't be pushed. Count: 5645
# The file 'image_data/13327.jpg' already exists, won't be pushed. Count: 5646
# The file 'image_data/14971.jpg' already exists, won't be pushed. Count: 5647
# The file 'image_data/14394.jpg' already exists, won't be pushed. Count: 5648
# The file 'image_data/17655.jpg' already exists, won't be pushed. Count: 5649
# The file 'image_data/15128.jpg' already exists, won't be pushed. Count: 5650
# The file 'image_data/16312.jpg' already exists, won't be pushed. Count: 5651
# The file 'image_data/13293.jpg' already exists, won't be pushed. Count: 5652
# The file 'image_data/17395.jpg' already exists, won't be pushed. Count: 5653
# The file 'image_data/16809.jpg' already exists, won't be pushed. Count: 5654
# The file 'image_data/17400.jpg' already exists, won't be pushed. Count: 5655
# The file 'image_data/10258.jpg' already exists, won't be pushed. Count: 5656
# The file 'image_data/12986.jpg' already exists, won't be pushed. Count: 5657
# The file 'image_data/10868.jpg' already exists, won't be pushed. Count: 5658
# The file 'image_data/12629.jpg' already exists, won't be pushed. Count: 5659
# The file 'image_data/13334.jpg' already exists, won't be pushed. Count: 5660
# The file 'image_data/12344.jpg' already exists, won't be pushed. Count: 5661
# The file 'image_data/16373.jpg' already exists, won't be pushed. Count: 5662
# The file 'image_data/13618.jpg' already exists, won't be pushed. Count: 5663
# The file 'image_data/11397.jpg' already exists, won't be pushed. Count: 5664
# The file 'image_data/14275.jpg' already exists, won't be pushed. Count: 5665
# The file 'image_data/11062.jpg' already exists, won't be pushed. Count: 5666
# The file 'image_data/14765.jpg' already exists, won't be pushed. Count: 5667
# The file 'image_data/16087.jpg' already exists, won't be pushed. Count: 5668
# The file 'image_data/12804.jpg' already exists, won't be pushed. Count: 5669
# The file 'image_data/13637.jpg' already exists, won't be pushed. Count: 5670
# The file 'image_data/15863.jpg' already exists, won't be pushed. Count: 5671
# The file 'image_data/13752.jpg' already exists, won't be pushed. Count: 5672
# The file 'image_data/16938.jpg' already exists, won't be pushed. Count: 5673
# The file 'image_data/11169.jpg' already exists, won't be pushed. Count: 5674
# The file 'image_data/15421.jpg' already exists, won't be pushed. Count: 5675
# The file 'image_data/13115.jpg' already exists, won't be pushed. Count: 5676
# The file 'image_data/17165.jpg' already exists, won't be pushed. Count: 5677
# The file 'image_data/12976.jpg' already exists, won't be pushed. Count: 5678
# The file 'image_data/15711.jpg' already exists, won't be pushed. Count: 5679
# The file 'image_data/13641.jpg' already exists, won't be pushed. Count: 5680
# The file 'image_data/15142.jpg' already exists, won't be pushed. Count: 5681
# The file 'image_data/15796.jpg' already exists, won't be pushed. Count: 5682
# The file 'image_data/10397.jpg' already exists, won't be pushed. Count: 5683
# The file 'image_data/14165.jpg' already exists, won't be pushed. Count: 5684
# The file 'image_data/14478.jpg' already exists, won't be pushed. Count: 5685
# The file 'image_data/17658.jpg' already exists, won't be pushed. Count: 5686
# The file 'image_data/14391.jpg' already exists, won't be pushed. Count: 5687
# The file 'image_data/12347.jpg' already exists, won't be pushed. Count: 5688
# The file 'image_data/13724.jpg' already exists, won't be pushed. Count: 5689
# The file 'image_data/17174.jpg' already exists, won't be pushed. Count: 5690
# The file 'image_data/16628.jpg' already exists, won't be pushed. Count: 5691
# The file 'image_data/13719.jpg' already exists, won't be pushed. Count: 5692
# The file 'image_data/14884.jpg' already exists, won't be pushed. Count: 5693
# The file 'image_data/13382.jpg' already exists, won't be pushed. Count: 5694
# The file 'image_data/15000.jpg' already exists, won't be pushed. Count: 5695
# The file 'image_data/13836.jpg' already exists, won't be pushed. Count: 5696
# The file 'image_data/18194.jpg' already exists, won't be pushed. Count: 5697
# The file 'image_data/17375.jpg' already exists, won't be pushed. Count: 5698
# The file 'image_data/14889.jpg' already exists, won't be pushed. Count: 5699
# The file 'image_data/16521.jpg' already exists, won't be pushed. Count: 5700
# The file 'image_data/10169.jpg' already exists, won't be pushed. Count: 5701
# The file 'image_data/13654.jpg' already exists, won't be pushed. Count: 5702
# The file 'image_data/11007.jpg' already exists, won't be pushed. Count: 5703
# The file 'image_data/12478.jpg' already exists, won't be pushed. Count: 5704
# The file 'image_data/13791.jpg' already exists, won't be pushed. Count: 5705
# The file 'image_data/12457.jpg' already exists, won't be pushed. Count: 5706
# The file 'image_data/17115.jpg' already exists, won't be pushed. Count: 5707
# The file 'image_data/11306.jpg' already exists, won't be pushed. Count: 5708
# The file 'image_data/11636.jpg' already exists, won't be pushed. Count: 5709
# The file 'image_data/10207.jpg' already exists, won't be pushed. Count: 5710
# The file 'image_data/18090.jpg' already exists, won't be pushed. Count: 5711
# The file 'image_data/10758.jpg' already exists, won't be pushed. Count: 5712
# The file 'image_data/11937.jpg' already exists, won't be pushed. Count: 5713
# The file 'image_data/10677.jpg' already exists, won't be pushed. Count: 5714
# The file 'image_data/11802.jpg' already exists, won't be pushed. Count: 5715
# The file 'image_data/16244.jpg' already exists, won't be pushed. Count: 5716
# The file 'image_data/14365.jpg' already exists, won't be pushed. Count: 5717
# The file 'image_data/17243.jpg' already exists, won't be pushed. Count: 5718
# The file 'image_data/17645.jpg' already exists, won't be pushed. Count: 5719
# The file 'image_data/11734.jpg' already exists, won't be pushed. Count: 5720
# The file 'image_data/11245.jpg' already exists, won't be pushed. Count: 5721
# The file 'image_data/12448.jpg' already exists, won't be pushed. Count: 5722
# The file 'image_data/11046.jpg' already exists, won't be pushed. Count: 5723
# The file 'image_data/14177.jpg' already exists, won't be pushed. Count: 5724
# The file 'image_data/12295.jpg' already exists, won't be pushed. Count: 5725
# The file 'image_data/11520.jpg' already exists, won't be pushed. Count: 5726
# The file 'image_data/10566.jpg' already exists, won't be pushed. Count: 5727
# The file 'image_data/18174.jpg' already exists, won't be pushed. Count: 5728
# The file 'image_data/14595.jpg' already exists, won't be pushed. Count: 5729
# The file 'image_data/17043.jpg' already exists, won't be pushed. Count: 5730
# The file 'image_data/17025.jpg' already exists, won't be pushed. Count: 5731
# The file 'image_data/15273.jpg' already exists, won't be pushed. Count: 5732
# The file 'image_data/16347.jpg' already exists, won't be pushed. Count: 5733
# Process finished

# %%
 # List objects in the specified folder path
folder_objects = list(bucket.list_blobs(prefix=destination_directory_images))

# Count the number of objects in the folder
num_objects = len(folder_objects)
print(f"Number of objects in '{destination_directory_images}': {num_objects}")
# Out:
# Number of objects in 'image_data/': 5733

# %%
# Upload the CSV file
csv_name = 'bbox_train.csv'
local_annotations_path = os.path.join(local_directory_annotations, csv_name)
blob = bucket.blob(csv_name)
blob.upload_from_filename(local_annotations_path)
print(f"File '{local_annotations_path}' uploaded to '{csv_name}'.")
# Out:
# File '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/bbox_train.csv' uploaded to 'bbox_train.csv'.

# %% [markdown]
# # Download data from BigQuery if it doesn't exist locally

# %%
def download_images_from_GCP(bucket_name, folder_path, destination_folder, overwrite = False):

    # Boolean to control if anything has been downloaded
    changes = False

    # Initialize the Cloud Storage client
    storage_client = storage.Client()

    # Get the bucket
    bucket = storage_client.bucket(bucket_name)

    # List objects in the specified folder path
    folder_objects = bucket.list_blobs(prefix=folder_path)

    # Create a local folder if it doesn't exist
    os.makedirs(destination_folder, exist_ok=True)

    # Download each image file from the folder
    for obj in folder_objects:
        # Construct local file path for downloading
        local_file_path = os.path.join(destination_folder, os.path.basename(obj.name))
        # Check if the file exists locally
        if overwrite or not os.path.exists(local_file_path):
            # Download the object to the local file
            obj.download_to_filename(local_file_path)
            print(f"Downloaded '{obj.name}' to '{local_file_path}'.")
            changes = True

    return changes

# %%
# Project path
project_root = os.path.dirname(os.getcwd())

# Lirectories path
local_image_folder = os.path.join(project_root, 'raw_data', 'image_data')
local_annot_folder = os.path.join(project_root, 'raw_data')

# Bucket paths
bucket_image_folder = 'image_data/'  # Destination folder in the bucket
csv_name = 'bbox_train.csv'

# %%
print('Updating local raw data from Google Cloud Storage...')
changes_csv = download_images_from_GCP(bucket_name, csv_name, local_annot_folder)
changes_images = download_images_from_GCP(bucket_name, bucket_image_folder, local_image_folder)
if not(changes_csv or changes_images):
    print('Local raw data folder is up to date')
# Out:
# Updating local raw data from Google Cloud Storage...
# Downloaded 'image_data/10041.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10041.jpg'.
# Downloaded 'image_data/10042.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10042.jpg'.
# Downloaded 'image_data/10043.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10043.jpg'.
# Downloaded 'image_data/10045.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10045.jpg'.
# Downloaded 'image_data/10046.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10046.jpg'.
# Downloaded 'image_data/10049.jpg' to '/home/klingenm/code/KlingenbergMarc/facetally/raw_data/image_data/10049.jpg'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb Cell 16 line 9
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> print('Updating local raw data from Google Cloud Storage...')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> changes_csv = download_images_from_GCP(bucket_name, csv_name, local_annot_folder)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> changes_images = download_images_from_GCP(bucket_name, bucket_image_folder, local_image_folder)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> if not(changes_csv or changes_images):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     print('Local raw data folder is up to date')
#
# /home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> # Check if the file exists locally
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> if overwrite or not os.path.exists(local_file_path):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     # Download the object to the local file
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     obj.download_to_filename(local_file_path)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     print(f"Downloaded '{obj.name}' to '{local_file_path}'.")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/klingenm/code/KlingenbergMarc/facetally/notebooks/load_data_google_marc.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     changes = True
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:1280, in Blob.download_to_filename(self, filename, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1172 def download_to_filename(
#    1173     self,
#    1174     filename,
#    (...)
#    1187     retry=DEFAULT_RETRY,
#    1188 ):
#    1189     """Download the contents of this blob into a named file.
#    1190
#    1191     If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1277     :raises: :class:`google.cloud.exceptions.NotFound`
#    1278     """
# -> 1280     self._handle_filename_and_download(
#    1281         filename,
#    1282         client=client,
#    1283         start=start,
#    1284         end=end,
#    1285         raw_download=raw_download,
#    1286         if_etag_match=if_etag_match,
#    1287         if_etag_not_match=if_etag_not_match,
#    1288         if_generation_match=if_generation_match,
#    1289         if_generation_not_match=if_generation_not_match,
#    1290         if_metageneration_match=if_metageneration_match,
#    1291         if_metageneration_not_match=if_metageneration_not_match,
#    1292         timeout=timeout,
#    1293         checksum=checksum,
#    1294         retry=retry,
#    1295     )
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:1156, in Blob._handle_filename_and_download(self, filename, *args, **kwargs)
#    1154 try:
#    1155     with open(filename, "wb") as file_obj:
# -> 1156         self._prep_and_do_download(
#    1157             file_obj,
#    1158             *args,
#    1159             **kwargs,
#    1160         )
#    1162 except resumable_media.DataCorruption:
#    1163     # Delete the corrupt downloaded file.
#    1164     os.remove(filename)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:4329, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4326 transport = client._http
#    4328 try:
# -> 4329     self._do_download(
#    4330         transport,
#    4331         file_obj,
#    4332         download_url,
#    4333         headers,
#    4334         start,
#    4335         end,
#    4336         raw_download,
#    4337         timeout=timeout,
#    4338         checksum=checksum,
#    4339         retry=retry,
#    4340     )
#    4341 except resumable_media.InvalidResponse as exc:
#    4342     _raise_from_invalid_response(exc)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/cloud/storage/blob.py:985, in Blob._do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#     976     download = klass(
#     977         download_url,
#     978         stream=file_obj,
#    (...)
#     982         checksum=checksum,
#     983     )
#     984     download._retry_strategy = retry_strategy
# --> 985     response = download.consume(transport, timeout=timeout)
#     986     self._extract_headers_from_download(response)
#     987 else:
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:237, in Download.consume(self, transport, timeout)
#     233         self._write_to_stream(result)
#     235     return result
# --> 237 return _request_helpers.wait_and_retry(
#     238     retriable_request, self._get_status_code, self._retry_strategy
#     239 )
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:233, in Download.consume.<locals>.retriable_request()
#     230             raise Exception(msg) from exc
#     231         self._bytes_downloaded = 0
# --> 233     self._write_to_stream(result)
#     235 return result
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/google/resumable_media/requests/download.py:123, in Download._write_to_stream(self, response)
#     119 local_checksum_object = _add_decoder(response.raw, checksum_object)
#     120 body_iter = response.iter_content(
#     121     chunk_size=_request_helpers._SINGLE_GET_CHUNK_SIZE, decode_unicode=False
#     122 )
# --> 123 for chunk in body_iter:
#     124     self._stream.write(chunk)
#     125     self._bytes_downloaded += len(chunk)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:934, in HTTPResponse.stream(self, amt, decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 934         data = self.read(amt=amt, decode_content=decode_content)
#     936         if data:
#     937             yield data
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:877, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     874     if len(self._decoded_buffer) >= amt:
#     875         return self._decoded_buffer.get(amt)
# --> 877 data = self._raw_read(amt)
#     879 flush_decoder = amt is None or (amt != 0 and not data)
#     881 if not data and len(self._decoded_buffer) == 0:
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:812, in HTTPResponse._raw_read(self, amt)
#     809 fp_closed = getattr(self._fp, "closed", False)
#     811 with self._error_catcher():
# --> 812     data = self._fp_read(amt) if not fp_closed else b""
#     813     if amt is not None and amt != 0 and not data:
#     814         # Platform-specific: Buggy versions of Python.
#     815         # Close the connection when no data is returned
#    (...)
#     820         # not properly close the connection in all cases. There is
#     821         # no harm in redundantly calling close.
#     822         self._fp.close()
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/urllib3/response.py:797, in HTTPResponse._fp_read(self, amt)
#     794     return buffer.getvalue()
#     795 else:
#     796     # StringIO doesn't like amt=None
# --> 797     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
