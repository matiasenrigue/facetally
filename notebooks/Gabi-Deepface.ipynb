# %% [markdown]
# ### Importing packages

# %%
# ! pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
# Out:
# 2023-12-04 16:44:33.279059: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# read image
img = cv2.imread('/Users/gabriellemacaire/Documents/github-profile.jpeg')

plt.imshow(img[:, :, : : -1])

# display that image
plt.show()

# %%
obj = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Documents/github-profile.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:06<00:00,  1.71s/it]
# [{'age': 30, 'region': {'x': 852, 'y': 1072, 'w': 716, 'h': 716}, 'gender': {'Woman': 19.331921637058258, 'Man': 80.66807985305786}, 'dominant_gender': 'Man', 'race': {'asian': 12.024874956898389, 'indian': 10.533446701374453, 'black': 17.787083553498004, 'white': 17.611588097309358, 'middle eastern': 12.262039617421605, 'latino hispanic': 29.7809678185563}, 'dominant_race': 'latino hispanic', 'emotion': {'angry': 0.1749164890497923, 'disgust': 3.49362174745238e-06, 'fear': 0.9344670921564102, 'happy': 97.43515849113464, 'sad': 0.20013826433569193, 'surprise': 0.5822117906063795, 'neutral': 0.6731015630066395}, 'dominant_emotion': 'happy'}]

# %%
print(obj[0:3])
# Out:
# [{'age': 30, 'region': {'x': 852, 'y': 1072, 'w': 716, 'h': 716}, 'gender': {'Woman': 19.331921637058258, 'Man': 80.66807985305786}, 'dominant_gender': 'Man', 'race': {'asian': 12.024874956898389, 'indian': 10.533446701374453, 'black': 17.787083553498004, 'white': 17.611588097309358, 'middle eastern': 12.262039617421605, 'latino hispanic': 29.7809678185563}, 'dominant_race': 'latino hispanic', 'emotion': {'angry': 0.1749164890497923, 'disgust': 3.49362174745238e-06, 'fear': 0.9344670921564102, 'happy': 97.43515849113464, 'sad': 0.20013826433569193, 'surprise': 0.5822117906063795, 'neutral': 0.6731015630066395}, 'dominant_emotion': 'happy'}]

# %%
img2 = cv2.imread('/Users/gabriellemacaire/Downloads/Nikita-test.jpeg')

# %%
obj2 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Nikita-test.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj2)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:07<00:00,  1.92s/it]
# [{'age': 31, 'region': {'x': 185, 'y': 62, 'w': 124, 'h': 124}, 'gender': {'Woman': 23.768992722034454, 'Man': 76.23100876808167}, 'dominant_gender': 'Man', 'race': {'asian': 1.1119872331619263, 'indian': 1.4415162615478039, 'black': 0.02715430746320635, 'white': 56.16462826728821, 'middle eastern': 30.32168745994568, 'latino hispanic': 10.933022201061249}, 'dominant_race': 'white', 'emotion': {'angry': 6.685962527990341, 'disgust': 2.042765913021216e-10, 'fear': 0.3946311306208372, 'happy': 1.0504819414336453e-05, 'sad': 89.47672843933105, 'surprise': 3.459136976857735e-06, 'neutral': 3.4426677972078323}, 'dominant_emotion': 'sad'}]

# %%
img3 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Marc.jpeg')

# %%
obj3 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Marc.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj3)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# [{'age': 31, 'region': {'x': 174, 'y': 83, 'w': 233, 'h': 233}, 'gender': {'Woman': 51.16924047470093, 'Man': 48.83075952529907}, 'dominant_gender': 'Woman', 'race': {'asian': 6.3272524671109, 'indian': 9.915017182529997, 'black': 2.851426771368192, 'white': 27.590887402945008, 'middle eastern': 28.73879842393389, 'latino hispanic': 24.57661626199581}, 'dominant_race': 'middle eastern', 'emotion': {'angry': 0.0004005899882031372, 'disgust': 1.675193672667774e-06, 'fear': 0.1745502115227282, 'happy': 98.78038167953491, 'sad': 0.013959083298686892, 'surprise': 0.014054740313440561, 'neutral': 1.0166574269533157}, 'dominant_emotion': 'happy'}]

# %%
img4 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Matias.jpeg')

# %%
obj4 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Matias.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj4)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.31it/s]
# [{'age': 31, 'region': {'x': 277, 'y': 224, 'w': 108, 'h': 108}, 'gender': {'Woman': 0.06220911745913327, 'Man': 99.93778467178345}, 'dominant_gender': 'Man', 'race': {'asian': 0.20548347383737564, 'indian': 0.21575596183538437, 'black': 0.008238793816417456, 'white': 82.62525796890259, 'middle eastern': 9.0360626578331, 'latino hispanic': 7.909200340509415}, 'dominant_race': 'white', 'emotion': {'angry': 0.4631521921993609, 'disgust': 2.2972648087521033e-05, 'fear': 7.163219580842232, 'happy': 0.017204580515244188, 'sad': 2.349748043700936, 'surprise': 0.0008104117597314554, 'neutral': 90.00584423576858}, 'dominant_emotion': 'neutral'}]

# %%
img4 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Andrea.jpeg')

# %%
obj4 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Andrea.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj4)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:04<00:00,  1.03s/it]
# [{'age': 25, 'region': {'x': 170, 'y': 146, 'w': 155, 'h': 155}, 'gender': {'Woman': 0.02931494382210076, 'Man': 99.97068047523499}, 'dominant_gender': 'Man', 'race': {'asian': 0.04381488513122559, 'indian': 0.15839421901593917, 'black': 0.013432007908959414, 'white': 78.0488775997685, 'middle eastern': 10.288136320599099, 'latino hispanic': 11.447342422446157}, 'dominant_race': 'white', 'emotion': {'angry': 2.3803848329415818, 'disgust': 0.053654591025685726, 'fear': 1.4270613820589413, 'happy': 57.63600812172938, 'sad': 7.541498246282234, 'surprise': 1.0525486128061183, 'neutral': 29.908849591544246}, 'dominant_emotion': 'happy'}]

# %%
img5 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Renzo.jpeg')

# %%
obj5 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Renzo.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/gabriellemacaire/code/Projects/facetally/notebooks/Gabi_training copy.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/Users/gabriellemacaire/code/Projects/facetally/notebooks/Gabi_training%20copy.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> obj5 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Renzo.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
#       <a href='vscode-notebook-cell:/Users/gabriellemacaire/code/Projects/facetally/notebooks/Gabi_training%20copy.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> print(obj5)
#
# File ~/.pyenv/versions/3.10.6/envs/facetally/lib/python3.10/site-packages/deepface/DeepFace.py:313, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     310 # ---------------------------------
#     311 resp_objects = []
# ...

# %%
img6 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Asia.jpeg')

# %%
obj6 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Asia.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj6)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:05<00:00,  1.39s/it]
# [{'age': 34, 'region': {'x': 80, 'y': 97, 'w': 297, 'h': 297}, 'gender': {'Woman': 36.4767462015152, 'Man': 63.52325677871704}, 'dominant_gender': 'Man', 'race': {'asian': 25.776423560167764, 'indian': 13.788492309361239, 'black': 6.8028573276315525, 'white': 15.725622518397719, 'middle eastern': 15.721354825577427, 'latino hispanic': 22.1852494588643}, 'dominant_race': 'asian', 'emotion': {'angry': 0.03460643553623173, 'disgust': 7.4273813752184796e-09, 'fear': 0.1273235032788517, 'happy': 11.967103151506373, 'sad': 0.013641284835098525, 'surprise': 0.1745247036866667, 'neutral': 87.68280075089936}, 'dominant_emotion': 'neutral'}]

# %%
img7 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-Maxi.jpeg')

# %%
obj7 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-Maxi.jpeg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj7)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:05<00:00,  1.44s/it]
# [{'age': 26, 'region': {'x': 197, 'y': 54, 'w': 111, 'h': 111}, 'gender': {'Woman': 0.06372926873154938, 'Man': 99.93627667427063}, 'dominant_gender': 'Man', 'race': {'asian': 27.566561102867126, 'indian': 11.030498892068863, 'black': 7.83538892865181, 'white': 13.211935758590698, 'middle eastern': 7.916722446680069, 'latino hispanic': 32.43889808654785}, 'dominant_race': 'latino hispanic', 'emotion': {'angry': 2.80977075128512e-07, 'disgust': 1.6964648940495996e-10, 'fear': 7.326538028130692e-08, 'happy': 99.6025084975372, 'sad': 0.0001511161438494084, 'surprise': 1.0322984942881051e-05, 'neutral': 0.39733122182860636}, 'dominant_emotion': 'happy'}]

# %%
img8 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-couple.jpg')

# %%
obj8 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Test-couple.jpg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj8)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.17it/s]
# [{'age': 36, 'region': {'x': 160, 'y': 57, 'w': 100, 'h': 100}, 'gender': {'Woman': 2.8517251848825254e-05, 'Man': 99.99997615814209}, 'dominant_gender': 'Man', 'race': {'asian': 0.29496122151613235, 'indian': 2.464940585196018, 'black': 0.9822326712310314, 'white': 61.80150508880615, 'middle eastern': 23.386798799037933, 'latino hispanic': 11.069564521312714}, 'dominant_race': 'white', 'emotion': {'angry': 0.0035908961496406303, 'disgust': 1.3117974559890411e-12, 'fear': 0.027902619747012226, 'happy': 99.96845721822467, 'sad': 7.028430942437354e-06, 'surprise': 1.1392918190306385e-05, 'neutral': 2.9971429447337142e-05}, 'dominant_emotion': 'happy'}]

# %%
img9 = cv2.imread('/Users/gabriellemacaire/Downloads/Test-trump.jpeg')

# %%
obj10 = DeepFace.analyze(img_path = "/Users/gabriellemacaire/Downloads/Donald_Trump_official_portrait.jpg", actions = ['age', 'gender', 'race', 'emotion'])
print(obj10)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:05<00:00,  1.37s/it]
# [{'age': 49, 'region': {'x': 382, 'y': 370, 'w': 471, 'h': 471}, 'gender': {'Woman': 0.0640681420918554, 'Man': 99.93593096733093}, 'dominant_gender': 'Man', 'race': {'asian': 44.01552975177765, 'indian': 5.924626067280769, 'black': 5.207936093211174, 'white': 19.246093928813934, 'middle eastern': 6.626805663108826, 'latino hispanic': 18.97900551557541}, 'dominant_race': 'asian', 'emotion': {'angry': 0.0008174412869266234, 'disgust': 1.7418540221303402e-08, 'fear': 7.41282065064297e-05, 'happy': 99.32562112808228, 'sad': 3.183568821896188e-05, 'surprise': 0.0033204647479578853, 'neutral': 0.6701362784951925}, 'dominant_emotion': 'happy'}]
